# %% [markdown]
# # Topic Modelling using NLP - Kaggle Job Descriptions Data

# %% [markdown]
# ## Part 2 - EDA, Feature extraction and Topic Modelling using NLP

# %%
import pandas as pd
import support_functions as sf

# %% [markdown]
# ### Load Kaggle dataset

# %%
k_jobs = pd.read_csv('../offline-datasets/kaggle-top30-job-descriptions/pre-processed/KaggleJobs.csv', na_filter=False)

# %%
k_jobs.head()
# Out:
#    Unnamed: 0 Location       Company                        Job Title  \
# 0           0                   None         Administrative Assistant
# 1           1                                Administrative Assistant
# 2           2           americanwest         Administrative Assistant
# 3           3                   None             Sales Representative
# 4           4                   None  Customer Service Representative
#
#                                      Job Description Salary  \
# 0  This Administrative Assistant position is resp...
# 1  ADMINISTRATIVE ASSISTANT Part Time The West Or...
# 2  Administrative Assistant -  In Bus 26yrs Fashi...
# 3  Are you ready for something new? Are you tired...
# 4  Superior Staff Resources is currently seeking ...
#
#                              E-mail
# 0
# 1  Kenneth.harker@healthcentral.org
# 2           barnard@americanwest.cc
# 3
# 4

# %%
# Drop 1st column
k_jobs.drop('Unnamed: 0', axis=1, inplace=True)

# %%
k_jobs.head()
# Out:
#   Location       Company                        Job Title  \
# 0                   None         Administrative Assistant
# 1                                Administrative Assistant
# 2           americanwest         Administrative Assistant
# 3                   None             Sales Representative
# 4                   None  Customer Service Representative
#
#                                      Job Description Salary  \
# 0  This Administrative Assistant position is resp...
# 1  ADMINISTRATIVE ASSISTANT Part Time The West Or...
# 2  Administrative Assistant -  In Bus 26yrs Fashi...
# 3  Are you ready for something new? Are you tired...
# 4  Superior Staff Resources is currently seeking ...
#
#                              E-mail
# 0
# 1  Kenneth.harker@healthcentral.org
# 2           barnard@americanwest.cc
# 3
# 4

# %% [markdown]
# ### Import Spacy Library

# %%
# Perform standard imports
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
# Import the displaCy library
from spacy import displacy

# %% [markdown]
# ### Transforming Job Descriptions to NLP docs using Spacy

# %% [markdown]
# #### Kaggle Job Descriptions

# %%
k_jobs.isnull().sum()
# Out:
# Location           0
# Company            0
# Job Title          0
# Job Description    0
# Salary             0
# E-mail             0
# dtype: int64

# %%
len(k_jobs['Job Description'])
# Out:
# 72292

# %%
len(k_jobs['Job Description'][:1000])
# Out:
# 1000

# %%
nlp_jd_k = []
for jd in k_jobs['Job Description'][:100]:
    nlp_jd_k.append(nlp(jd))

# %%
for i in nlp_jd_k:
    sf.show_entities(i)
    print('\n\n')
# Out:
# Word - GPE - Countries, cities, states
# Excel - PRODUCT - Objects, vehicles, foods, etc. (not services)
# OutlookOther Administrative - ORG - Companies, agencies, institutions, etc.
# 2 Years - DATE - Absolute or relative dates or periods
# 10key - DATE - Absolute or relative dates or periods
# etc.)Strong - GPE - Countries, cities, states
# skillsStrong - PERSON - People, including fictional
#
#
#
# the Board of Trustees - ORG - Companies, agencies, institutions, etc.
# 3+ years - DATE - Absolute or relative dates or periods
# Microsoft Word - PERSON - People, including fictional
# Excel - PRODUCT - Objects, vehicles, foods, etc. (not services)
# Power Point - PRODUCT - Objects, vehicles, foods, etc. (not services)
# QuickBooks - ORG - Companies, agencies, institutions, etc.
# Kenneth.harker@healthcentral.org EOE Source - Orlando Sentinel - ORG - Companies, agencies, institutions, etc.
#
#
#
# Handbag - PERSON - People, including fictional
# Inventory Depmts - PERSON - People, including fictional
# SF52144As - PERSON - People, including fictional
# the Western Industry - ORG - Companies, agencies, institutions, etc.
# American - NORP - Nationalities or religious or political groups
# Administrative - ORG - Companies, agencies, institutions, etc.
# the Sales Department - ORG - Companies, agencies, institutions, etc.
# the New Product Development - ORG - Companies, agencies, institutions, etc.
# EVP - ORG - Companies, agencies, institutions, etc.
# Sales - ORG - Companies, agencies, institutions, etc.
# Operations Administrative Assistant - ORG - Companies, agencies, institutions, etc.
# the Sales Department - ORG - Companies, agencies, institutions, etc.
# New Product Development - ORG - Companies, agencies, institutions, etc.
# JOB - ORG - Companies, agencies, institutions, etc.
# the Exec VP - LOC - Non-GPE locations, mountain ranges, bodies of water
# Sales Department - ORG - Companies, agencies, institutions, etc.
# Product Development - ORG - Companies, agencies, institutions, etc.
# Assist Territory - ORG - Companies, agencies, institutions, etc.
# Daily - DATE - Absolute or relative dates or periods
# weekly - DATE - Absolute or relative dates or periods
# two - CARDINAL - Numerals that do not fall under another type
# weekly - DATE - Absolute or relative dates or periods
# New Product Development - ORG - Companies, agencies, institutions, etc.
# Inventory Data - ORG - Companies, agencies, institutions, etc.
#   - NORP - Nationalities or religious or political groups
#
#
#
# 10 - CARDINAL - Numerals that do not fall under another type
# this quarter - DATE - Absolute or relative dates or periods
# Excellent Customer Service - ORG - Companies, agencies, institutions, etc.
#
#
#
# Superior Staff Resources - ORG - Companies, agencies, institutions, etc.
# Customer Service Representative/Cashier - ORG - Companies, agencies, institutions, etc.
#   - NORP - Nationalities or religious or political groups
# Albany - GPE - Countries, cities, states
# NY - GPE - Countries, cities, states
#           - GPE - Countries, cities, states
# CSR - ORG - Companies, agencies, institutions, etc.
#           - GPE - Countries, cities, states
# CSR - ORG - Companies, agencies, institutions, etc.
#           - PERSON - People, including fictional
# CSR - ORG - Companies, agencies, institutions, etc.
#           - GPE - Countries, cities, states
# CSR - ORG - Companies, agencies, institutions, etc.
# daily - DATE - Absolute or relative dates or periods
#           - PERSON - People, including fictional
# CSR - ORG - Companies, agencies, institutions, etc.
#           - GPE - Countries, cities, states
# CSR - ORG - Companies, agencies, institutions, etc.
# Vector - PRODUCT - Objects, vehicles, foods, etc. (not services)
#          The CSR - WORK_OF_ART - Titles of books, songs, etc.
# daily - DATE - Absolute or relative dates or periods
#           - GPE - Countries, cities, states
# CSR - ORG - Companies, agencies, institutions, etc.
# assignment.•           - ORG - Companies, agencies, institutions, etc.
# CSR - ORG - Companies, agencies, institutions, etc.
#           - PERSON - People, including fictional
# CSR - ORG - Companies, agencies, institutions, etc.
# Workleader - PERSON - People, including fictional
# Supervisor - GPE - Countries, cities, states
#   - NORP - Nationalities or religious or political groups
# Superior - FAC - Buildings, airports, highways, bridges, etc.
# today - DATE - Absolute or relative dates or periods
# EOE M/F/D/V - ORG - Companies, agencies, institutions, etc.
#
#
#
# Schweitzer Engineering Laboratories - ORG - Companies, agencies, institutions, etc.
# SEL - ORG - Companies, agencies, institutions, etc.
# Customer Service Representative - ORG - Companies, agencies, institutions, etc.
# Dothan - GPE - Countries, cities, states
# Alabama - GPE - Countries, cities, states
# Dothan - PERSON - People, including fictional
# Alabama - GPE - Countries, cities, states
# Dothan - GPE - Countries, cities, states
# Southern Hospitality - ORG - Companies, agencies, institutions, etc.
# Customer Service - ORG - Companies, agencies, institutions, etc.
#
#
#
# Portal Development Team - ORG - Companies, agencies, institutions, etc.
# the BHS Information Services Department - ORG - Companies, agencies, institutions, etc.
# Louisville - GPE - Countries, cities, states
# KY - GPE - Countries, cities, states
# Java - ORG - Companies, agencies, institutions, etc.
# Follows - PERSON - People, including fictional
# Resolves - ORG - Companies, agencies, institutions, etc.
# Java - ORG - Companies, agencies, institutions, etc.
# Spring - DATE - Absolute or relative dates or periods
# Hibernate - ORG - Companies, agencies, institutions, etc.
# XML - GPE - Countries, cities, states
# SQL - ORG - Companies, agencies, institutions, etc.
# Java - ORG - Companies, agencies, institutions, etc.
#
#
#
#                         HSI & The Department of Commerce - ORG - Companies, agencies, institutions, etc.
# DOC - ORG - Companies, agencies, institutions, etc.
# 6) month - DATE - Absolute or relative dates or periods
# Java EE - ORG - Companies, agencies, institutions, etc.
# 1st - DATE - Absolute or relative dates or periods
# 2nd - ORDINAL - "first", "second", etc.
# the Rate Bureau - ORG - Companies, agencies, institutions, etc.
# WC - ORG - Companies, agencies, institutions, etc.
# 4 - CARDINAL - Numerals that do not fall under another type
#
#
#
#   - NORP - Nationalities or religious or political groups
# Maintain - PERSON - People, including fictional
# Employ - PERSON - People, including fictional
# MS Office - ORG - Companies, agencies, institutions, etc.
# Create - ORG - Companies, agencies, institutions, etc.
# Coordinate - PERSON - People, including fictional
# Act - PERSON - People, including fictional
# Book - WORK_OF_ART - Titles of books, songs, etc.
# three - CARDINAL - Numerals that do not fall under another type
# Develop - PERSON - People, including fictional
# Create PowerPoint - FAC - Buildings, airports, highways, bridges, etc.
#
#
#
# Roanoke Capital Management - ORG - Companies, agencies, institutions, etc.
# 426 - CARDINAL - Numerals that do not fall under another type
# Main Street - FAC - Buildings, airports, highways, bridges, etc.
# El Segundo - GPE - Countries, cities, states
# CA 90245 - ORG - Companies, agencies, institutions, etc.
# Los Angeles Times - ORG - Companies, agencies, institutions, etc.
# 2012 - DATE - Absolute or relative dates or periods
#
#
#
# VoIP - NORP - Nationalities or religious or political groups
#          - PERSON - People, including fictional
# Anticipate - ORG - Companies, agencies, institutions, etc.
# Pro - ORG - Companies, agencies, institutions, etc.
# Build - ORG - Companies, agencies, institutions, etc.
# Establish - NORP - Nationalities or religious or political groups
# Communicate - ORG - Companies, agencies, institutions, etc.
# Develop - PRODUCT - Objects, vehicles, foods, etc. (not services)
# 26 years - DATE - Absolute or relative dates or periods
# the United States - GPE - Countries, cities, states
#   - ORDINAL - "first", "second", etc.
# Equal Opportunity Employer - ORG - Companies, agencies, institutions, etc.
#
#
#
# Application Developer-Senior-JavaSummary - PERSON - People, including fictional
# Merrill Corporation - ORG - Companies, agencies, institutions, etc.
# Merrill - ORG - Companies, agencies, institutions, etc.
# Adhere - NORP - Nationalities or religious or political groups
# the Merrill Project Life Cycle - ORG - Companies, agencies, institutions, etc.
#   - NORP - Nationalities or religious or political groups
# ITIL - ORG - Companies, agencies, institutions, etc.
# ISO - ORG - Companies, agencies, institutions, etc.
# Utilize - ORG - Companies, agencies, institutions, etc.
# Adhere - NORP - Nationalities or religious or political groups
#
#
#
# GC Services - ORG - Companies, agencies, institutions, etc.
# Teleservices - ORG - Companies, agencies, institutions, etc.
# Collections - PERSON - People, including fictional
# Business Development - ORG - Companies, agencies, institutions, etc.
# Houston - GPE - Countries, cities, states
# TX - ORG - Companies, agencies, institutions, etc.
# Elgin - GPE - Countries, cities, states
#   - NORP - Nationalities or religious or political groups
# Generate - ORG - Companies, agencies, institutions, etc.
# Build - ORG - Companies, agencies, institutions, etc.
# B2B - DATE - Absolute or relative dates or periods
#
#
#
# Mosaic Sales Solutions - ORG - Companies, agencies, institutions, etc.
# Work in Marketing - ORG - Companies, agencies, institutions, etc.
# Media - ORG - Companies, agencies, institutions, etc.
# Business Intelligence - ORG - Companies, agencies, institutions, etc.
# the Project Management Office - ORG - Companies, agencies, institutions, etc.
# Irving - GPE - Countries, cities, states
# TX - ORG - Companies, agencies, institutions, etc.
# Dallas - GPE - Countries, cities, states
# Identify - PERSON - People, including fictional
# Collaborate - ORG - Companies, agencies, institutions, etc.
#
#
#
# 110-year - CARDINAL - Numerals that do not fall under another type
# an Executive Assistant - ORG - Companies, agencies, institutions, etc.
# CFO - ORG - Companies, agencies, institutions, etc.
# COO - ORG - Companies, agencies, institutions, etc.
# Adams Produce Company - ORG - Companies, agencies, institutions, etc.
# EOE - ORG - Companies, agencies, institutions, etc.
#
#
#
# Management Executives - ORG - Companies, agencies, institutions, etc.
# day - DATE - Absolute or relative dates or periods
# hours - TIME - Times smaller than a day
#
#
#
#      - Direct - PERSON - People, including fictional
# Hire -      Maintenance       Technician       - ORG - Companies, agencies, institutions, etc.
#        - ORG - Companies, agencies, institutions, etc.
# PLC - ORG - Companies, agencies, institutions, etc.
#        - GPE - Countries, cities, states
#       - GPE - Countries, cities, states
#       - GPE - Countries, cities, states
#
#
#
# Cookeville Regional Medical Center - ORG - Companies, agencies, institutions, etc.
#      Administrative Assistant - ORG - Companies, agencies, institutions, etc.
#       - GPE - Countries, cities, states
# Physician       Services - ORG - Companies, agencies, institutions, etc.
# daily - DATE - Absolute or relative dates or periods
#  High School Diploma - ORG - Companies, agencies, institutions, etc.
# Secretarial - GPE - Countries, cities, states
# Business School - ORG - Companies, agencies, institutions, etc.
# five years continuous years - DATE - Absolute or relative dates or periods
#        - GPE - Countries, cities, states
#        - GPE - Countries, cities, states
#        - GPE - Countries, cities, states
# Qualified Candidates       Apply - ORG - Companies, agencies, institutions, etc.
# Cookeville Regional Medical Center       - ORG - Companies, agencies, institutions, etc.
# 1 - CARDINAL - Numerals that do not fall under another type
# Medical Center Boulevard - FAC - Buildings, airports, highways, bridges, etc.
# Cookeville - GPE - Countries, cities, states
# Tennessee - GPE - Countries, cities, states
# 931 - CARDINAL - Numerals that do not fall under another type
# 931 - CARDINAL - Numerals that do not fall under another type
#      Crmchealth.org - PERSON - People, including fictional
#       - GPE - Countries, cities, states
# Murfreesboro Daily News Journal - ORG - Companies, agencies, institutions, etc.
#
#
#
# CA - PERSON - People, including fictional
# Excel - PRODUCT - Objects, vehicles, foods, etc. (not services)
# PowerPoint - ORG - Companies, agencies, institutions, etc.
# NetSuite - NORP - Nationalities or religious or political groups
# Finance - ORG - Companies, agencies, institutions, etc.
# Finance - ORG - Companies, agencies, institutions, etc.
# 1-2 - CARDINAL - Numerals that do not fall under another type
# Analyze - GPE - Countries, cities, states
#
#
#
# NAME - ORG - Companies, agencies, institutions, etc.
#  MAINTENANCE TECHNICIAN JOB DESCRIPTION - ORG - Companies, agencies, institutions, etc.
# Assist - NORP - Nationalities or religious or political groups
# 10 - CARDINAL - Numerals that do not fall under another type
# Assist - NORP - Nationalities or religious or political groups
# skills.11 - GPE - Countries, cities, states
# knowledge.12 - PERSON - People, including fictional
#   - ORG - Companies, agencies, institutions, etc.
# required.14 - PERSON - People, including fictional
# Associates degree - QUANTITY - Measurements, as of weight or distance
# Industrial Maintenance - ORG - Companies, agencies, institutions, etc.
#
#
#
# Project Manager Job - ORG - Companies, agencies, institutions, etc.
#  An Engineering & Construction Firm - ORG - Companies, agencies, institutions, etc.
# Birmingham - GPE - Countries, cities, states
# AL - GPE - Countries, cities, states
# 5-10 years - DATE - Absolute or relative dates or periods
# Virtual Construction Integration - ORG - Companies, agencies, institutions, etc.
# Navisworks Manage - LOC - Non-GPE locations, mountain ranges, bodies of water
# Construction Sequencing - ORG - Companies, agencies, institutions, etc.
# BIM - ORG - Companies, agencies, institutions, etc.
# Building Science, Construction Management, Civil Engineering - ORG - Companies, agencies, institutions, etc.
# Architecture - ORG - Companies, agencies, institutions, etc.
# Bachelors - ORG - Companies, agencies, institutions, etc.
# years - DATE - Absolute or relative dates or periods
# BIM Technology - ORG - Companies, agencies, institutions, etc.
# Navisworks - ORG - Companies, agencies, institutions, etc.
# Revit Architecture - PERSON - People, including fictional
# MEP - ORG - Companies, agencies, institutions, etc.
# Revit Structure - PERSON - People, including fictional
# Autocad - ORG - Companies, agencies, institutions, etc.
# the Healthcare Facility Construction Industry - ORG - Companies, agencies, institutions, etc.
# Drive - GPE - Countries, cities, states
# 401 - CARDINAL - Numerals that do not fall under another type
# K Business - ORG - Companies, agencies, institutions, etc.
#   - NORP - Nationalities or religious or political groups
# $80,000 - $100,000 - MONEY - Monetary values, including unit
# 8-10% - PERCENT - Percentage, including "%"
#   Keywords - PERSON - People, including fictional
# first - ORDINAL - "first", "second", etc.
# 3d - CARDINAL - Numerals that do not fall under another type
# Project Manager Job - ORG - Companies, agencies, institutions, etc.
#
#
#
# Project Manager Job - ORG - Companies, agencies, institutions, etc.
# 9-12 month - DATE - Absolute or relative dates or periods
# Northern California - LOC - Non-GPE locations, mountain ranges, bodies of water
# between $55/HR - $60/HR - MONEY - Monetary values, including unit
# ProjectManages - PERSON - People, including fictional
#   - NORP - Nationalities or religious or political groups
# Requirements7-10 years - PERSON - People, including fictional
# Project ManagementExperience - ORG - Companies, agencies, institutions, etc.
# O&G5-7 years - DATE - Absolute or relative dates or periods
# Microsoft ProjectBachelors - ORG - Companies, agencies, institutions, etc.
# EngineeringValve - ORG - Companies, agencies, institutions, etc.
# experienceBenefitsRandstad Engineering - ORG - Companies, agencies, institutions, etc.
# 401 - CARDINAL - Numerals that do not fall under another type
# K - ORG - Companies, agencies, institutions, etc.
# Keywords - PRODUCT - Objects, vehicles, foods, etc. (not services)
# Project Manager Job - ORG - Companies, agencies, institutions, etc.
#
#
#
# Project Manager Job   - ORG - Companies, agencies, institutions, etc.
# National Power Systems - ORG - Companies, agencies, institutions, etc.
# two - CARDINAL - Numerals that do not fall under another type
# Project Managers - one Project - ORG - Companies, agencies, institutions, etc.
# Fort Meyers - GPE - Countries, cities, states
# Georgetown - GPE - Countries, cities, states
# TX - ORG - Companies, agencies, institutions, etc.
# FL - ORG - Companies, agencies, institutions, etc.
# TX - ORG - Companies, agencies, institutions, etc.
# 6 months - DATE - Absolute or relative dates or periods
# Central Minnesota - LOC - Non-GPE locations, mountain ranges, bodies of water
# FL - ORG - Companies, agencies, institutions, etc.
# TX - ORG - Companies, agencies, institutions, etc.
# Project Managers - ORG - Companies, agencies, institutions, etc.
# Minnesota - GPE - Countries, cities, states
# Florida - GPE - Countries, cities, states
# Texas - GPE - Countries, cities, states
# ResponsibilitiesEstimating - ORG - Companies, agencies, institutions, etc.
# Excel - PRODUCT - Objects, vehicles, foods, etc. (not services)
# Microsoft - ORG - Companies, agencies, institutions, etc.
# ProjectCreating - PRODUCT - Objects, vehicles, foods, etc. (not services)
# QA/QC - ORG - Companies, agencies, institutions, etc.
# EPC - ORG - Companies, agencies, institutions, etc.
# Microsoft - ORG - Companies, agencies, institutions, etc.
# Excel - PRODUCT - Objects, vehicles, foods, etc. (not services)
#   Keywords - PRODUCT - Objects, vehicles, foods, etc. (not services)
# Project Manager Job - ORG - Companies, agencies, institutions, etc.
#
#
#
# Project Manager Job - ORG - Companies, agencies, institutions, etc.
# Immediate - ORG - Companies, agencies, institutions, etc.
# SCADA - ORG - Companies, agencies, institutions, etc.
# Visio - PERSON - People, including fictional
# Midwest - LOC - Non-GPE locations, mountain ranges, bodies of water
# ResponsibilitiesResponsible - ORG - Companies, agencies, institutions, etc.
# requirementsRequirementsRequires - PRODUCT - Objects, vehicles, foods, etc. (not services)
# Bachelor - PERSON - People, including fictional
# equivalent years - DATE - Absolute or relative dates or periods
# Process - PRODUCT - Objects, vehicles, foods, etc. (not services)
# Project  Engineer - ORG - Companies, agencies, institutions, etc.
# Project Management - ORG - Companies, agencies, institutions, etc.
# Visio - PERSON - People, including fictional
# MS Excel - ORG - Companies, agencies, institutions, etc.
# Power Point - PRODUCT - Objects, vehicles, foods, etc. (not services)
# Word - PRODUCT - Objects, vehicles, foods, etc. (not services)
# Key Performance Indicators - ORG - Companies, agencies, institutions, etc.
# Keywords - PRODUCT - Objects, vehicles, foods, etc. (not services)
# b2b - DATE - Absolute or relative dates or periods
# Project Manager Job - ORG - Companies, agencies, institutions, etc.
#
#
#
# APS Healthcare - ORG - Companies, agencies, institutions, etc.
# APS - ORG - Companies, agencies, institutions, etc.
# the day-to-day - DATE - Absolute or relative dates or periods
# Health Intelligence - ORG - Companies, agencies, institutions, etc.
# Madison - PERSON - People, including fictional
# WI - GPE - Countries, cities, states
# a day - DATE - Absolute or relative dates or periods
# Schedules - PERSON - People, including fictional
# May - DATE - Absolute or relative dates or periods
# School Diploma - ORG - Companies, agencies, institutions, etc.
# GED - ORG - Companies, agencies, institutions, etc.
# 1-3 years - DATE - Absolute or relative dates or periods
# Microsoft Office - ORG - Companies, agencies, institutions, etc.
# Outlook - GPE - Countries, cities, states
# Word - PERSON - People, including fictional
# Excel - PRODUCT - Objects, vehicles, foods, etc. (not services)
# PowerPoint.•Must - ORG - Companies, agencies, institutions, etc.
#
#
#
# Navistar International Corporation - ORG - Companies, agencies, institutions, etc.
# MaxxForce - ORG - Companies, agencies, institutions, etc.
# IC Bus™ - ORG - Companies, agencies, institutions, etc.
# Monaco - GPE - Countries, cities, states
# RV - ORG - Companies, agencies, institutions, etc.
# Workhorse - ORG - Companies, agencies, institutions, etc.
# International Truck Formed - PERSON - People, including fictional
# 1902 - DATE - Absolute or relative dates or periods
# International - ORG - Companies, agencies, institutions, etc.
# nearly 1,000 - CARDINAL - Numerals that do not fall under another type
# the United States - GPE - Countries, cities, states
# Canada - GPE - Countries, cities, states
# Brazil - GPE - Countries, cities, states
# Mexico - GPE - Countries, cities, states
# more than 60 - CARDINAL - Numerals that do not fall under another type
# 90 - CARDINAL - Numerals that do not fall under another type
# Bachelor - PERSON - People, including fictional
# 2 years - DATE - Absolute or relative dates or periods
# 18 - CARDINAL - Numerals that do not fall under another type
# Degree in Communications - ORG - Companies, agencies, institutions, etc.
# BusinessStrong - ORG - Companies, agencies, institutions, etc.
# Skills including Office Suite - ORG - Companies, agencies, institutions, etc.
# ProjectPrevious - ORG - Companies, agencies, institutions, etc.
# Global Experience  Strong - PERSON - People, including fictional
# Six Sigma Experience - FAC - Buildings, airports, highways, bridges, etc.
# BackgroundPositive AttitudeEthics - ORG - Companies, agencies, institutions, etc.
# Navistar - GPE - Countries, cities, states
# ValuesDrive - ORG - Companies, agencies, institutions, etc.
# ResultsIntellectual HorsepowerInterpersonal SavvyCross-Cultural AgilityProblem SolvingVisit - ORG - Companies, agencies, institutions, etc.
# Navistar.com - ORG - Companies, agencies, institutions, etc.
# Equal Opportunity Employer - ORG - Companies, agencies, institutions, etc.
# The Future Rides On Us - ORG - Companies, agencies, institutions, etc.
#
#
#
# Saint Luke's - PERSON - People, including fictional
# Home Care & HospiceDepartment - ORG - Companies, agencies, institutions, etc.
# HHC ANDERSON HOME CARESchedule - ORG - Companies, agencies, institutions, etc.
# DayHours - GPE - Countries, cities, states
#   8-5Job Details:     Registration/Licensure/Certification 1 year - ORG - Companies, agencies, institutions, etc.
# The Physical Therapist - ORG - Companies, agencies, institutions, etc.
# “Physical Therapy Standards of Practice - ORG - Companies, agencies, institutions, etc.
# Medicare - ORG - Companies, agencies, institutions, etc.
# JCAHO - ORG - Companies, agencies, institutions, etc.
# Saint Luke’s Health System Home Care - ORG - Companies, agencies, institutions, etc.
# Hospice - WORK_OF_ART - Titles of books, songs, etc.
#   Effective - ORG - Companies, agencies, institutions, etc.
# August 1, 2011 - DATE - Absolute or relative dates or periods
# Saint Luke's Health System - ORG - Companies, agencies, institutions, etc.
# Application for Employment - ORG - Companies, agencies, institutions, etc.
# 1 - CARDINAL - Numerals that do not fall under another type
# 2 - CARDINAL - Numerals that do not fall under another type
# System - FAC - Buildings, airports, highways, bridges, etc.
# System - FAC - Buildings, airports, highways, bridges, etc.
#
#
#
# Provides - NORP - Nationalities or religious or political groups
# Maintains - PERSON - People, including fictional
# Prepares - PERSON - People, including fictional
# Microsoft Office - ORG - Companies, agencies, institutions, etc.
# Maintains - PERSON - People, including fictional
# Prepares - PERSON - People, including fictional
# files minutes - TIME - Times smaller than a day
# the Campus Resource Center - ORG - Companies, agencies, institutions, etc.
# Assists - GPE - Countries, cities, states
# TPI - ORG - Companies, agencies, institutions, etc.
# The Pacific Institute - ORG - Companies, agencies, institutions, etc.
# Daymar Colleges Group - ORG - Companies, agencies, institutions, etc.
# Organizes - PERSON - People, including fictional
# minutes - TIME - Times smaller than a day
# 2 - CARDINAL - Numerals that do not fall under another type
# Assists - NORP - Nationalities or religious or political groups
# Assists - NORP - Nationalities or religious or political groups
# Drafts - PERSON - People, including fictional
# Arranges - PERSON - People, including fictional
# Prepares - PERSON - People, including fictional
# Travels - ORG - Companies, agencies, institutions, etc.
# Maintains - PERSON - People, including fictional
# 3 - CARDINAL - Numerals that do not fall under another type
# the Campus Leadership Team - ORG - Companies, agencies, institutions, etc.
# Sets - ORG - Companies, agencies, institutions, etc.
#
#
#
# every day - DATE - Absolute or relative dates or periods
#   - ORDINAL - "first", "second", etc.
# all day - DATE - Absolute or relative dates or periods
# Management Career - ORG - Companies, agencies, institutions, etc.
# Team Waterway - ORG - Companies, agencies, institutions, etc.
# Carwash - PERSON - People, including fictional
# over 40 years - DATE - Absolute or relative dates or periods
# #1 - CARDINAL - Numerals that do not fall under another type
# 19 - CARDINAL - Numerals that do not fall under another type
# 4 - CARDINAL - Numerals that do not fall under another type
# St. Louis - GPE - Countries, cities, states
# Kansas City - GPE - Countries, cities, states
# Denver - GPE - Countries, cities, states
# Cleveland - GPE - Countries, cities, states
# Management Development Program - ORG - Companies, agencies, institutions, etc.
# The Ideal Candidate - PRODUCT - Objects, vehicles, foods, etc. (not services)
# Bachelor - PERSON - People, including fictional
# one - CARDINAL - Numerals that do not fall under another type
# Confident, Friendly and Competitive - ORG - Companies, agencies, institutions, etc.
# A Hard Worker - WORK_OF_ART - Titles of books, songs, etc.
# The Boss     - PERSON - People, including fictional
# Accomplishments and Achievements   - ORG - Companies, agencies, institutions, etc.
# Management Development Program - ORG - Companies, agencies, institutions, etc.
# just 90 days - DATE - Absolute or relative dates or periods
# two - CARDINAL - Numerals that do not fall under another type
# their first year - DATE - Absolute or relative dates or periods
# three years - DATE - Absolute or relative dates or periods
# $33,000 to $38,000 - MONEY - Monetary values, including unit
# that first year - DATE - Absolute or relative dates or periods
# $45,000 to $65,000 - MONEY - Monetary values, including unit
# Salaried Position - ORG - Companies, agencies, institutions, etc.
# Rank Completion and Performance Bonuses - ORG - Companies, agencies, institutions, etc.
# Career Path - LAW - Named documents made into laws.
# Long-Term Investment Matching     Tuition Reimbursement - ORG - Companies, agencies, institutions, etc.
# High Quality Co-Workers - ORG - Companies, agencies, institutions, etc.
# Outdoor Work Environment - ORG - Companies, agencies, institutions, etc.
# Casual Work Attire - ORG - Companies, agencies, institutions, etc.
# Discounts on Gas - ORG - Companies, agencies, institutions, etc.
#
#
#
#      - DATE - Absolute or relative dates or periods
# Select Staffing’s - ORG - Companies, agencies, institutions, etc.
#     Maintaining - PERSON - People, including fictional
# Personnel Supervisors - PERSON - People, including fictional
# weekly - DATE - Absolute or relative dates or periods
# Staffing - GPE - Countries, cities, states
# Select - GPE - Countries, cities, states
# today - DATE - Absolute or relative dates or periods
#
#
#
#      - DATE - Absolute or relative dates or periods
# SelectRemedy - ORG - Companies, agencies, institutions, etc.
#     Maintaining - PERSON - People, including fictional
# Personnel Supervisors - PERSON - People, including fictional
# weekly - DATE - Absolute or relative dates or periods
# Staffing - GPE - Countries, cities, states
#
#
#
# at least 5 years - DATE - Absolute or relative dates or periods
# a Staff Accountant - ORG - Companies, agencies, institutions, etc.
# Companies/Divisions - ORG - Companies, agencies, institutions, etc.
# Familiarity - ORG - Companies, agencies, institutions, etc.
# Distribution - ORG - Companies, agencies, institutions, etc.
#
#
#
#      - DATE - Absolute or relative dates or periods
# Select Staffing’s - ORG - Companies, agencies, institutions, etc.
#     Maintaining - PERSON - People, including fictional
# Personnel Supervisors - PERSON - People, including fictional
# weekly - DATE - Absolute or relative dates or periods
# Staffing - GPE - Countries, cities, states
# Select - GPE - Countries, cities, states
# today - DATE - Absolute or relative dates or periods
#
#
#
#      - DATE - Absolute or relative dates or periods
# Select Staffing’s - ORG - Companies, agencies, institutions, etc.
#     Maintaining - PERSON - People, including fictional
# Personnel Supervisors - PERSON - People, including fictional
# weekly - DATE - Absolute or relative dates or periods
# Staffing - GPE - Countries, cities, states
# Select - GPE - Countries, cities, states
# today - DATE - Absolute or relative dates or periods
#
#
#
# Provides - NORP - Nationalities or religious or political groups
# May Include: - DATE - Absolute or relative dates or periods
#
#
#
# American West Worldwide Express - ORG - Companies, agencies, institutions, etc.
# The Inside Sales Representative - ORG - Companies, agencies, institutions, etc.
# Inside Sales Representative - ORG - Companies, agencies, institutions, etc.
# monthly - DATE - Absolute or relative dates or periods
#
#
#
# Operations - ORG - Companies, agencies, institutions, etc.
# ARAMARK Uniform Services - ORG - Companies, agencies, institutions, etc.
# AUS - ORG - Companies, agencies, institutions, etc.
# The Executive Assistant - ORG - Companies, agencies, institutions, etc.
# two - CARDINAL - Numerals that do not fall under another type
# Processes - PERSON - People, including fictional
# Reviews - NORP - Nationalities or religious or political groups
# Coordinates - PERSON - People, including fictional
# Prepares - PERSON - People, including fictional
# Maintains - PERSON - People, including fictional
# Develops - PERSON - People, including fictional
# Performs - ORG - Companies, agencies, institutions, etc.
#    - ORG - Companies, agencies, institutions, etc.
# Compose - PERSON - People, including fictional
# Coordinates - PERSON - People, including fictional
#
#
#
# Metro Storage LLC - ORG - Companies, agencies, institutions, etc.
# Lake Forest - GPE - Countries, cities, states
# Illinois - GPE - Countries, cities, states
# Illinois - GPE - Countries, cities, states
# first - ORDINAL - "first", "second", etc.
# 1973 - DATE - Absolute or relative dates or periods
# over a billion dollars - MONEY - Monetary values, including unit
# over 100 - CARDINAL - Numerals that do not fall under another type
# Maintenance Technicians - ORG - Companies, agencies, institutions, etc.
# Assist - NORP - Nationalities or religious or political groups
# Scavenger, Pest Control - ORG - Companies, agencies, institutions, etc.
# Snowplowing - GPE - Countries, cities, states
# Landscaping - GPE - Countries, cities, states
# monthly - DATE - Absolute or relative dates or periods
# annual - DATE - Absolute or relative dates or periods
#    - ORG - Companies, agencies, institutions, etc.
# 401 - CARDINAL - Numerals that do not fall under another type
# Roth - PERSON - People, including fictional
#
#
#
# Burlington - GPE - Countries, cities, states
#   - NORP - Nationalities or religious or political groups
# Multi - PERSON - People, including fictional
# Prioritize - ORG - Companies, agencies, institutions, etc.
# Word - GPE - Countries, cities, states
# Excel - PRODUCT - Objects, vehicles, foods, etc. (not services)
# Powerpoint - ORG - Companies, agencies, institutions, etc.
#
#
#
# Account Executive- - ORG - Companies, agencies, institutions, etc.
# #1music - MONEY - Monetary values, including unit
# Muzak Account Executives - ORG - Companies, agencies, institutions, etc.
# Muzak - ORG - Companies, agencies, institutions, etc.
# Marketing On Hold and - ORG - Companies, agencies, institutions, etc.
# the DISH Network - PRODUCT - Objects, vehicles, foods, etc. (not services)
# Duties:\tDevelop - ORG - Companies, agencies, institutions, etc.
# Muzak - ORG - Companies, agencies, institutions, etc.
# appropriate.\tConsultative - CARDINAL - Numerals that do not fall under another type
# 401(k).\tYour - CARDINAL - Numerals that do not fall under another type
# month.\tSignificant - CARDINAL - Numerals that do not fall under another type
# Muzak - NORP - Nationalities or religious or political groups
# today - DATE - Absolute or relative dates or periods
# Muzak LLC - ORG - Companies, agencies, institutions, etc.
# an Equal Opportunity Employer - ORG - Companies, agencies, institutions, etc.
#
#
#
# The Account Development Project - ORG - Companies, agencies, institutions, etc.
# (PM - TIME - Times smaller than a day
# Accounts - ORG - Companies, agencies, institutions, etc.
# PM - ORDINAL - "first", "second", etc.
# Account - GPE - Countries, cities, states
# Muzak and Mood Media - ORG - Companies, agencies, institutions, etc.
# Voice - ORG - Companies, agencies, institutions, etc.
# Touch - ORG - Companies, agencies, institutions, etc.
# Media - ORG - Companies, agencies, institutions, etc.
# Administration, Central Operations, Field Operations - ORG - Companies, agencies, institutions, etc.
# Prosound/Design - ORG - Companies, agencies, institutions, etc.
# SLA - ORG - Companies, agencies, institutions, etc.
# Muzak Company Operations - ORG - Companies, agencies, institutions, etc.
#   - NORP - Nationalities or religious or political groups
#         Change - PERSON - People, including fictional
#         Resource - PERSON - People, including fictional
# an Equal Opportunity Employer - ORG - Companies, agencies, institutions, etc.
#
#
#
# Assist Office Staff - ORG - Companies, agencies, institutions, etc.
# Data Entry/Filing Duties - ORG - Companies, agencies, institutions, etc.
#
#
#
#   - NORP - Nationalities or religious or political groups
# Custom Jewelry - ORG - Companies, agencies, institutions, etc.
# Gift Delivery - PERSON - People, including fictional
# Gift - PERSON - People, including fictional
# Jewelry Appraisal - ORG - Companies, agencies, institutions, etc.
# Jewelry Repair - PERSON - People, including fictional
# Day - PERSON - People, including fictional
# Great Retail Hours - ORG - Companies, agencies, institutions, etc.
# 10-6 Monday through Friday - DATE - Absolute or relative dates or periods
# 10-5 - TIME - Times smaller than a day
# Saturday - DATE - Absolute or relative dates or periods
# Sundays - DATE - Absolute or relative dates or periods
#
#
#
#         Seeking Internal Senior Accoutant - PERSON - People, including fictional
# Calabasas - GPE - Countries, cities, states
# CA SUMMARY - LOC - Non-GPE locations, mountain ranges, bodies of water
# Compiles - ORG - Companies, agencies, institutions, etc.
# monthly - DATE - Absolute or relative dates or periods
# monthly - DATE - Absolute or relative dates or periods
# quarterly - DATE - Absolute or relative dates or periods
# Reviews - NORP - Nationalities or religious or political groups
# SOX - ORG - Companies, agencies, institutions, etc.
# Communicate - ORG - Companies, agencies, institutions, etc.
# Ad - ORG - Companies, agencies, institutions, etc.
#
#
#
# BOYDS TEAM - PERSON - People, including fictional
#   - PERSON - People, including fictional
# Beverage Lovers - ORG - Companies, agencies, institutions, etc.
# Boyd Coffee Company - ORG - Companies, agencies, institutions, etc.
# Portland - GPE - Countries, cities, states
# Roastery - ORG - Companies, agencies, institutions, etc.
# more than 110 years - DATE - Absolute or relative dates or periods
# Restaurants to Hotels to Convenience Stores - ORG - Companies, agencies, institutions, etc.
# Roastery - ORG - Companies, agencies, institutions, etc.
# first - ORDINAL - "first", "second", etc.
# a Senior Accountant - ORG - Companies, agencies, institutions, etc.
# Portland - GPE - Countries, cities, states
#   - ORG - Companies, agencies, institutions, etc.
#         Verification - PERSON - People, including fictional
#         Income - PERSON - People, including fictional
#   - NORP - Nationalities or religious or political groups
#         Fixed - PERSON - People, including fictional
#         Cash - PERSON - People, including fictional
#          - PERSON - People, including fictional
# Month end - DATE - Absolute or relative dates or periods
#         Budgeting - PERSON - People, including fictional
# reporting• - ORG - Companies, agencies, institutions, etc.
#         Mentor - PERSON - People, including fictional
#         Analysis - PERSON - People, including fictional
#           - GPE - Countries, cities, states
#
#
#
# Allegheny County - GPE - Countries, cities, states
# the Corporate Controller - ORG - Companies, agencies, institutions, etc.
# Specific - PERSON - People, including fictional
# … - GPE - Countries, cities, states
# Analyze - GPE - Countries, cities, states
# monthly - DATE - Absolute or relative dates or periods
#       - GPE - Countries, cities, states
# month-end - DATE - Absolute or relative dates or periods
#
#
#
# United Subcontractors, Inc. - GPE - Countries, cities, states
# Construction Services - ORG - Companies, agencies, institutions, etc.
# Colorado Springs - GPE - Countries, cities, states
# Establish - NORP - Nationalities or religious or political groups
# Identify - GPE - Countries, cities, states
#
#
#
# The Affiliate Services Account Executive - ORG - Companies, agencies, institutions, etc.
# monthly - DATE - Absolute or relative dates or periods
# Build - ORG - Companies, agencies, institutions, etc.
#
#
#
# Receptionist Sand Companies, Inc. - ORG - Companies, agencies, institutions, etc.
# first - ORDINAL - "first", "second", etc.
#   - ORDINAL - "first", "second", etc.
# MS Office - ORG - Companies, agencies, institutions, etc.
# Sand Companies, Inc - ORG - Companies, agencies, institutions, etc.
# PO Box 727Waite Park, MN  56387HR@SandCompanies.comFax: - ORG - Companies, agencies, institutions, etc.
# 320 - CARDINAL - Numerals that do not fall under another type
# AAP - ORG - Companies, agencies, institutions, etc.
#
#
#
# Georgia - GPE - Countries, cities, states
# Alabama - GPE - Countries, cities, states
#
#
#
# Washington DC - GPE - Countries, cities, states
# Northern VirginiaThe - LOC - Non-GPE locations, mountain ranges, bodies of water
# Merchant Services Company - ORG - Companies, agencies, institutions, etc.
# First Data - ORG - Companies, agencies, institutions, etc.
# over 1,400 - CARDINAL - Numerals that do not fall under another type
# Account Executives - ORG - Companies, agencies, institutions, etc.
# three - CARDINAL - Numerals that do not fall under another type
#   - NORP - Nationalities or religious or political groups
# 3 month - DATE - Absolute or relative dates or periods
# annual - DATE - Absolute or relative dates or periods
# Regional Sales - ORG - Companies, agencies, institutions, etc.
# First Data - ORG - Companies, agencies, institutions, etc.
# MS Office - ORG - Companies, agencies, institutions, etc.
#
#
#
# Assist - NORP - Nationalities or religious or political groups
# Customer Service - ORG - Companies, agencies, institutions, etc.
# Q/A - ORG - Companies, agencies, institutions, etc.
# Work - PERSON - People, including fictional
# Analyzes - PERSON - People, including fictional
# Support - PERSON - People, including fictional
# approximately 30% - PERCENT - Percentage, including "%"
# MasterCard - ORG - Companies, agencies, institutions, etc.
# Microsoft Office Suite - ORG - Companies, agencies, institutions, etc.
# Microsoft Project Ability - ORG - Companies, agencies, institutions, etc.
# more than one - CARDINAL - Numerals that do not fall under another type
# Bachelors Degree - PERSON - People, including fictional
# Business, Accounting or Marketing - ORG - Companies, agencies, institutions, etc.
# 3 years - DATE - Absolute or relative dates or periods
# Business Analyst - ORG - Companies, agencies, institutions, etc.
#
#
#
# Chicago - GPE - Countries, cities, states
# Merchant Services Company - ORG - Companies, agencies, institutions, etc.
# First Data - ORG - Companies, agencies, institutions, etc.
# Account Executive - ORG - Companies, agencies, institutions, etc.
#   - NORP - Nationalities or religious or political groups
# 9 month - DATE - Absolute or relative dates or periods
# annual - DATE - Absolute or relative dates or periods
# First Data - ORG - Companies, agencies, institutions, etc.
# MS Office - ORG - Companies, agencies, institutions, etc.
# Korean - NORP - Nationalities or religious or political groups
#
#
#
# Merchant Services Company - ORG - Companies, agencies, institutions, etc.
# First Data - ORG - Companies, agencies, institutions, etc.
# over 1,400 - CARDINAL - Numerals that do not fall under another type
# Account Executives - ORG - Companies, agencies, institutions, etc.
# three - CARDINAL - Numerals that do not fall under another type
#   - NORP - Nationalities or religious or political groups
# 3 month - DATE - Absolute or relative dates or periods
# annual - DATE - Absolute or relative dates or periods
# Regional Sales - ORG - Companies, agencies, institutions, etc.
# First Data - ORG - Companies, agencies, institutions, etc.
# Oakland - GPE - Countries, cities, states
# CAThe - ORG - Companies, agencies, institutions, etc.
# MS Office - ORG - Companies, agencies, institutions, etc.
#
#
#
# Jackson - PERSON - People, including fictional
# Merchant Services Company - ORG - Companies, agencies, institutions, etc.
# First Data - ORG - Companies, agencies, institutions, etc.
# Account Executive - ORG - Companies, agencies, institutions, etc.
#   - NORP - Nationalities or religious or political groups
# 9 month - DATE - Absolute or relative dates or periods
# annual - DATE - Absolute or relative dates or periods
# First Data - ORG - Companies, agencies, institutions, etc.
# MS Office - ORG - Companies, agencies, institutions, etc.
#
#
#
# Join - PERSON - People, including fictional
# Pawn - PERSON - People, including fictional
# Responsibilities - GPE - Countries, cities, states
# Provides - ORG - Companies, agencies, institutions, etc.
# Maintains - PERSON - People, including fictional
# daily - DATE - Absolute or relative dates or periods
# Maximizes - NORP - Nationalities or religious or political groups
#
#
#
# 75-100 - CARDINAL - Numerals that do not fall under another type
# Target - ORG - Companies, agencies, institutions, etc.
#
#
#
# Sterling Heights - GPE - Countries, cities, states
# MI - GPE - Countries, cities, states
# PM Capability Development - ORG - Companies, agencies, institutions, etc.
# Sector - WORK_OF_ART - Titles of books, songs, etc.
# Product Lines - PERSON - People, including fictional
# Business Areas - ORG - Companies, agencies, institutions, etc.
# Contract Reviews and Phase Reviews - ORG - Companies, agencies, institutions, etc.
# Business Risk and Opportunity Management - ORG - Companies, agencies, institutions, etc.
# PM - ORDINAL - "first", "second", etc.
# IM&T - ORG - Companies, agencies, institutions, etc.
# Comms - PERSON - People, including fictional
# PM - ORDINAL - "first", "second", etc.
#
#
#
# Restaurant Management / Shift Supervisors - ORG - Companies, agencies, institutions, etc.
# Hardee's - ORG - Companies, agencies, institutions, etc.
# Quality, Service - ORG - Companies, agencies, institutions, etc.
# Paid Training - PERSON - People, including fictional
# Paid Time Off - ORG - Companies, agencies, institutions, etc.
# Health Insurance - ORG - Companies, agencies, institutions, etc.
#
#
#
# Questar - GPE - Countries, cities, states
# Account Executives - ORG - Companies, agencies, institutions, etc.
# North America - LOC - Non-GPE locations, mountain ranges, bodies of water
# Questar - GPE - Countries, cities, states
# 360 - CARDINAL - Numerals that do not fall under another type
# 2000 - DATE - Absolute or relative dates or periods
# Questar - GPE - Countries, cities, states
# Questar - GPE - Countries, cities, states
#       - GPE - Countries, cities, states
# Questar - GPE - Countries, cities, states
# Questar - GPE - Countries, cities, states
# 401(k - CARDINAL - Numerals that do not fall under another type
# 651 - CARDINAL - Numerals that do not fall under another type
#
#
#
# set(Mac - ORG - Companies, agencies, institutions, etc.
#   - ORG - Companies, agencies, institutions, etc.
# 3 - CARDINAL - Numerals that do not fall under another type
#   - Assist - NORP - Nationalities or religious or political groups
# Business Development - ORG - Companies, agencies, institutions, etc.
# RecruitmentAdvertising Agency - ORG - Companies, agencies, institutions, etc.
# MacExperience Required - ORG - Companies, agencies, institutions, etc.
# weekly - DATE - Absolute or relative dates or periods
# Macskills - ORG - Companies, agencies, institutions, etc.
# Quark - GPE - Countries, cities, states
# Filemaker - PERSON - People, including fictional
# Photoshop - GPE - Countries, cities, states
# Interested - PERSON - People, including fictional
#
#
#
# Photo Seller - ORG - Companies, agencies, institutions, etc.
# Inside Sales Team - ORG - Companies, agencies, institutions, etc.
# WORK - ORG - Companies, agencies, institutions, etc.
# Wheels, Steals ‘ - ORG - Companies, agencies, institutions, etc.
# almost 40 years - DATE - Absolute or relative dates or periods
# Recycler.com - ORG - Companies, agencies, institutions, etc.
# 65 - CARDINAL - Numerals that do not fall under another type
# 10th - ORDINAL - "first", "second", etc.
# hourly - TIME - Times smaller than a day
# 401k - CARDINAL - Numerals that do not fall under another type
#
#
#
# Customer Service Representative 3 - ORG - Companies, agencies, institutions, etc.
# Interline Brands, Inc. - ORG - Companies, agencies, institutions, etc.
# three - CARDINAL - Numerals that do not fall under another type
# Service Representatives - ORG - Companies, agencies, institutions, etc.
# Tulsa - GPE - Countries, cities, states
# Call Center - ORG - Companies, agencies, institutions, etc.
# Monday - DATE - Absolute or relative dates or periods
# and work hours - TIME - Times smaller than a day
# 10:30 AM to 7 PM - TIME - Times smaller than a day
# Customer Service Representative - ORG - Companies, agencies, institutions, etc.
# 80-100 - CARDINAL - Numerals that do not fall under another type
#
#
#
# No named entities found.
#
#
#
# Rocklin Irving Marketing Solutions - ORG - Companies, agencies, institutions, etc.
#
#
#
# Cleveland - GPE - Countries, cities, states
# daily - DATE - Absolute or relative dates or periods
# at least 2 years - DATE - Absolute or relative dates or periods
# East Royalton Rd - LOC - Non-GPE locations, mountain ranges, bodies of water
# Broadview Hts - PERSON - People, including fictional
#
#
#
# COMPANY OVERVIEW Founded - ORG - Companies, agencies, institutions, etc.
# 1881 - DATE - Absolute or relative dates or periods
# Schwaab, Inc. - ORG - Companies, agencies, institutions, etc.
# over 75 - CARDINAL - Numerals that do not fall under another type
# 125 years - DATE - Absolute or relative dates or periods
#
#
#
#  Staff Accountant Senior Care Centers of America, Inc. - ORG - Companies, agencies, institutions, etc.
# SCCA - ORG - Companies, agencies, institutions, etc.
# 1988 - DATE - Absolute or relative dates or periods
# Trevose - ORG - Companies, agencies, institutions, etc.
# Pennsylvania - GPE - Countries, cities, states
# 76 - CARDINAL - Numerals that do not fall under another type
# 11 - CARDINAL - Numerals that do not fall under another type
# the Senior Care Centers of America - ORG - Companies, agencies, institutions, etc.
# Active Day - DATE - Absolute or relative dates or periods
# SCCA - ORG - Companies, agencies, institutions, etc.
# daily - DATE - Absolute or relative dates or periods
# Active Day - DATE - Absolute or relative dates or periods
# Staff Accountant - ORG - Companies, agencies, institutions, etc.
# Prepare - NORP - Nationalities or religious or political groups
# monthly - DATE - Absolute or relative dates or periods
# monthly - DATE - Absolute or relative dates or periods
# annual - DATE - Absolute or relative dates or periods
#
#
#
# Customer Service Representative - ORG - Companies, agencies, institutions, etc.
# Maplehurst - ORG - Companies, agencies, institutions, etc.
# Customer Master File Maintenance - ORG - Companies, agencies, institutions, etc.
#
#
#
# ReceptionistFast Enterprises - ORG - Companies, agencies, institutions, etc.
# LLC - ORG - Companies, agencies, institutions, etc.
# 1998 - DATE - Absolute or relative dates or periods
# ...
# Switchgear - ORG - Companies, agencies, institutions, etc.
# Lighting, Lighting Controls - ORG - Companies, agencies, institutions, etc.
# Data-Comm - ORG - Companies, agencies, institutions, etc.
# Automation - ORG - Companies, agencies, institutions, etc.
# Home Automation - ORG - Companies, agencies, institutions, etc.
# Responsibilities - GPE - Countries, cities, states
# Securing - PERSON - People, including fictional
# 3E - ORG - Companies, agencies, institutions, etc.
# Outside Sales - ORG - Companies, agencies, institutions, etc.
# 3E - ORG - Companies, agencies, institutions, etc.
#
#
#
# SCOPE - PERSON - People, including fictional
# COO - ORG - Companies, agencies, institutions, etc.
# COO - ORG - Companies, agencies, institutions, etc.
# COO - ORG - Companies, agencies, institutions, etc.
# COO - ORG - Companies, agencies, institutions, etc.
# CMHA - ORG - Companies, agencies, institutions, etc.
# Accounts Receivable - ORG - Companies, agencies, institutions, etc.
# month - DATE - Absolute or relative dates or periods
# monthly - DATE - Absolute or relative dates or periods
# quarterly - DATE - Absolute or relative dates or periods
# annual - DATE - Absolute or relative dates or periods
#
#
#
# Position Title: - ORG - Companies, agencies, institutions, etc.
# The Client Project - ORG - Companies, agencies, institutions, etc.
# first - ORDINAL - "first", "second", etc.
# third - ORDINAL - "first", "second", etc.
# ORCC - ORG - Companies, agencies, institutions, etc.
# first - ORDINAL - "first", "second", etc.
# Draft - ORG - Companies, agencies, institutions, etc.
# requests.\tDevelop - LOC - Non-GPE locations, mountain ranges, bodies of water
# necessary.\tWhere - CARDINAL - Numerals that do not fall under another type
# personnel.\tIdentify - DATE - Absolute or relative dates or periods
# team.\tIdentify - DATE - Absolute or relative dates or periods
# path.\tPlan - DATE - Absolute or relative dates or periods
# deliverables.\tDevelop - PRODUCT - Objects, vehicles, foods, etc. (not services)
# company.\tConduct - NORP - Nationalities or religious or political groups
# the month end - DATE - Absolute or relative dates or periods
# SLA - ORG - Companies, agencies, institutions, etc.
#
#
#
# Salary Range - PERSON - People, including fictional
# 48,926.00 - MONEY - Monetary values, including unit
# Marketing StatementMetroPlus Health - ORG - Companies, agencies, institutions, etc.
# over 25 years - DATE - Absolute or relative dates or periods
# 4 - CARDINAL - Numerals that do not fall under another type
# 5 - CARDINAL - Numerals that do not fall under another type
# NYC - GPE - Countries, cities, states
# MetroPlus - PRODUCT - Objects, vehicles, foods, etc. (not services)
# Medicaid Managed Care - LOC - Non-GPE locations, mountain ranges, bodies of water
# Child Health Plus, Family Health - WORK_OF_ART - Titles of books, songs, etc.
# Medicaid HIV Special - PRODUCT - Objects, vehicles, foods, etc. (not services)
# Plan - WORK_OF_ART - Titles of books, songs, etc.
# five - CARDINAL - Numerals that do not fall under another type
# Medicare - ORG - Companies, agencies, institutions, etc.
# 450,000 - CARDINAL - Numerals that do not fall under another type
# MetroPlus - PRODUCT - Objects, vehicles, foods, etc. (not services)
# 1 - MONEY - Monetary values, including unit
# Medicaid Managed Care - GPE - Countries, cities, states
# New York City - GPE - Countries, cities, states
# five - CARDINAL - Numerals that do not fall under another type
# the last six years - DATE - Absolute or relative dates or periods
# the NY State Department of Health - ORG - Companies, agencies, institutions, etc.
# Job - CARDINAL - Numerals that do not fall under another type
# Summary - GPE - Countries, cities, states
#   - ORDINAL - "first", "second", etc.
# the date - DATE - Absolute or relative dates or periods
# May - DATE - Absolute or relative dates or periods
#
#
#
# Baker Tilly – Appleton - PERSON - People, including fictional
# WIReceptionist Overview - ORG - Companies, agencies, institutions, etc.
# Baker - PERSON - People, including fictional
# Krause - ORG - Companies, agencies, institutions, etc.
# Baker Tilly Virchow Krause - ORG - Companies, agencies, institutions, etc.
# one - CARDINAL - Numerals that do not fall under another type
# 20 - CARDINAL - Numerals that do not fall under another type
# the United States - GPE - Countries, cities, states
# today - DATE - Absolute or relative dates or periods
# Receptionist - PERSON - People, including fictional
# Appleton - ORG - Companies, agencies, institutions, etc.
# WI - GPE - Countries, cities, states
# Baker - PERSON - People, including fictional
# more than 1400 - CARDINAL - Numerals that do not fall under another type
# Baker Tilly - PERSON - People, including fictional
# Virchow Krause - PERSON - People, including fictional
# Baker Tilly International - ORG - Companies, agencies, institutions, etc.
# 8th - ORDINAL - "first", "second", etc.
# $3 billion - MONEY - Monetary values, including unit
# more than 110 - CARDINAL - Numerals that do not fall under another type
# first - ORDINAL - "first", "second", etc.
# Maintains - PERSON - People, including fictional
# May - DATE - Absolute or relative dates or periods
# May - DATE - Absolute or relative dates or periods
# May - DATE - Absolute or relative dates or periods
#
#
#
# Baker Tilly – Madison - PERSON - People, including fictional
# WI                      - PERSON - People, including fictional
#   - NORP - Nationalities or religious or political groups
# Baker - PERSON - People, including fictional
# Krause - ORG - Companies, agencies, institutions, etc.
# Baker Tilly Virchow Krause - ORG - Companies, agencies, institutions, etc.
# one - CARDINAL - Numerals that do not fall under another type
# 20 - CARDINAL - Numerals that do not fall under another type
# the United States - GPE - Countries, cities, states
# today - DATE - Absolute or relative dates or periods
# Madison - PERSON - People, including fictional
# WI - ORG - Companies, agencies, institutions, etc.
# an Administrative Assistant - ORG - Companies, agencies, institutions, etc.
# State & Local Government Practice - ORG - Companies, agencies, institutions, etc.
# Accountants - ORG - Companies, agencies, institutions, etc.
# Baker Tilly - PERSON - People, including fictional
# more than 1400 - CARDINAL - Numerals that do not fall under another type
# Baker Tilly - PERSON - People, including fictional
# Virchow Krause - PERSON - People, including fictional
# Baker Tilly International - ORG - Companies, agencies, institutions, etc.
# 8th - ORDINAL - "first", "second", etc.
# $3 billion - MONEY - Monetary values, including unit
# more than 110 - CARDINAL - Numerals that do not fall under another type
# Responsibilities - GPE - Countries, cities, states
# minutes - TIME - Times smaller than a day
# Create - PRODUCT - Objects, vehicles, foods, etc. (not services)
#
#
#
# Summary Performs - ORG - Companies, agencies, institutions, etc.
#   - NORP - Nationalities or religious or political groups
#                                                                                                                   - CARDINAL - Numerals that do not fall under another type
# PM - TIME - Times smaller than a day
# CNC - ORG - Companies, agencies, institutions, etc.
#  Secondary Responsibilities - ORG - Companies, agencies, institutions, etc.
# 5S+1 - CARDINAL - Numerals that do not fall under another type
# Safety & Housekeeping)     Participate - ORG - Companies, agencies, institutions, etc.
# Preventive Maintenance      - ORG - Companies, agencies, institutions, etc.
#
#
#
# Summary Performs - ORG - Companies, agencies, institutions, etc.
#   - NORP - Nationalities or religious or political groups
#                                                                                                                   - CARDINAL - Numerals that do not fall under another type
# PM - TIME - Times smaller than a day
# CNC - ORG - Companies, agencies, institutions, etc.
#  Secondary Responsibilities - ORG - Companies, agencies, institutions, etc.
# 5S+1 - CARDINAL - Numerals that do not fall under another type
# Safety & Housekeeping)     Participate - ORG - Companies, agencies, institutions, etc.
# Preventive Maintenance      - ORG - Companies, agencies, institutions, etc.
#
#
#
# Financial Analyst - ORG - Companies, agencies, institutions, etc.
# one - CARDINAL - Numerals that do not fall under another type
# three - CARDINAL - Numerals that do not fall under another type
# the United States - GPE - Countries, cities, states
# over 40 years - DATE - Absolute or relative dates or periods
# the Northwest Chicago - FAC - Buildings, airports, highways, bridges, etc.
# New York - GPE - Countries, cities, states
# Los Angeles - GPE - Countries, cities, states
# Atlanta - GPE - Countries, cities, states
# Financial Analyst - ORG - Companies, agencies, institutions, etc.
# monthly, quarterly - DATE - Absolute or relative dates or periods
# year end - DATE - Absolute or relative dates or periods
# Strong Excel - PERSON - People, including fictional
# Accounting or Business - ORG - Companies, agencies, institutions, etc.
# several years - DATE - Absolute or relative dates or periods
#
#
#
# Customer Service Representative GRADE - ORG - Companies, agencies, institutions, etc.
# 3SUMMARY - CARDINAL - Numerals that do not fall under another type
# daily - DATE - Absolute or relative dates or periods
# Cross-sell Association - ORG - Companies, agencies, institutions, etc.
# SCOPE OF - PERSON - People, including fictional
# Association - GPE - Countries, cities, states
# TYPICAL - ORG - Companies, agencies, institutions, etc.
# Place - PERSON - People, including fictional
# Purchase/Redeem Savings Bonds for Association - ORG - Companies, agencies, institutions, etc.
# Debit/Transaction - ORG - Companies, agencies, institutions, etc.
# Association - ORG - Companies, agencies, institutions, etc.
# Prepare - ORG - Companies, agencies, institutions, etc.
# On-Us Checking - ORG - Companies, agencies, institutions, etc.
# QUALFICATIONS - ORG - Companies, agencies, institutions, etc.
# Requires High School - ORG - Companies, agencies, institutions, etc.
# “Teller Training" - ORG - Companies, agencies, institutions, etc.
# Association - ORG - Companies, agencies, institutions, etc.
# Association Policies and Federal Regulations - ORG - Companies, agencies, institutions, etc.
# Bank Secrecy Act - LAW - Named documents made into laws.
# Customer Identification Program - ORG - Companies, agencies, institutions, etc.
# Office of Foreign Assets Control - ORG - Companies, agencies, institutions, etc.
# Privacy - ORG - Companies, agencies, institutions, etc.
# Financial Privacy - ORG - Companies, agencies, institutions, etc.
#
#
#
# Thomas Marine Systems - PERSON - People, including fictional
# Inc. - GPE - Countries, cities, states
# the Marine Air Conditioning - LAW - Named documents made into laws.
# South Florida - GPE - Countries, cities, states
# over 20 years - DATE - Absolute or relative dates or periods
# Miami - GPE - Countries, cities, states
# Ft Lauderdale - GPE - Countries, cities, states
#
#
#
# Hedge Fund - ORG - Companies, agencies, institutions, etc.
# Mid-Westchester - ORG - Companies, agencies, institutions, etc.
#       - GPE - Countries, cities, states
# Organize - GPE - Countries, cities, states
# last minute - TIME - Times smaller than a day
# Excel - PRODUCT - Objects, vehicles, foods, etc. (not services)
#
#
#
# Primary Job Functions - ORG - Companies, agencies, institutions, etc.
# Reviews - NORP - Nationalities or religious or political groups
# Processes - PERSON - People, including fictional
# Assists - NORP - Nationalities or religious or political groups
#
#
#
#   - NORP - Nationalities or religious or political groups
#
#
#
# Juno - PERSON - People, including fictional
# Art Fest - WORK_OF_ART - Titles of books, songs, etc.
# the Sea - LOC - Non-GPE locations, mountain ranges, bodies of water
# MAC Computers - ORG - Companies, agencies, institutions, etc.
# Photoshop - GPE - Countries, cities, states
#
#
#
# MAINTENANCE TECHNICIANR & D Thiel - ORG - Companies, agencies, institutions, etc.
# Division of Carpenter Contractors of America, Inc. - ORG - Companies, agencies, institutions, etc.
# Chicagoland - ORG - Companies, agencies, institutions, etc.
# Maintenance Technician - ORG - Companies, agencies, institutions, etc.
# Belvidere - GPE - Countries, cities, states
#   - NORP - Nationalities or religious or political groups
# 3 - CARDINAL - Numerals that do not fall under another type
# years - DATE - Absolute or relative dates or periods
# 815/544-7132 - DATE - Absolute or relative dates or periods
#
#
#
# daily - DATE - Absolute or relative dates or periods
# Scan - NORP - Nationalities or religious or political groups
# SharePoint - ORG - Companies, agencies, institutions, etc.
# Oversee - GPE - Countries, cities, states
# SharePoint - ORG - Companies, agencies, institutions, etc.
# Creating - ORG - Companies, agencies, institutions, etc.
# Board Committee - ORG - Companies, agencies, institutions, etc.
# Assist Board - ORG - Companies, agencies, institutions, etc.
# Board Meeting - ORG - Companies, agencies, institutions, etc.
# Board - ORG - Companies, agencies, institutions, etc.
# Board - ORG - Companies, agencies, institutions, etc.
#
#
#
# Las Vegas - GPE - Countries, cities, states
# Ace Asphalt - PERSON - People, including fictional
# Account Executive - ORG - Companies, agencies, institutions, etc.
# Las Vegas - GPE - Countries, cities, states
# Ace Asphalt’s - PERSON - People, including fictional
# Account Executive - ORG - Companies, agencies, institutions, etc.
# Las Vegas - GPE - Countries, cities, states
# Ace Asphalt - PERSON - People, including fictional
# Arizona - GPE - Countries, cities, states
# U.S. - GPE - Countries, cities, states
# Arizona - GPE - Countries, cities, states
# Phoenix - GPE - Countries, cities, states
# Tucson - GPE - Countries, cities, states
# Albuquerque - GPE - Countries, cities, states
# Las Vegas - GPE - Countries, cities, states
# Southern Nevada - ORG - Companies, agencies, institutions, etc.
# Ace Asphalt - PERSON - People, including fictional
# five or more years - DATE - Absolute or relative dates or periods
# Asphalt - PERSON - People, including fictional
# Las Vegas - GPE - Countries, cities, states
# Nevada - GPE - Countries, cities, states
# Company - ORG - Companies, agencies, institutions, etc.
# 401k - CARDINAL - Numerals that do not fall under another type
# 50% - PERCENT - Percentage, including "%"
# Ace Asphalt - PERSON - People, including fictional
# Phoenix Arizona - GPE - Countries, cities, states
# the Las Vegas - LOC - Non-GPE locations, mountain ranges, bodies of water
# Nevada - GPE - Countries, cities, states
# Las Vegas - GPE - Countries, cities, states
# ASAP - NORP - Nationalities or religious or political groups
# Ace Asphalt - PERSON - People, including fictional
#     - PERSON - People, including fictional
# Jeff - PERSON - People, including fictional
# BohneHuman Resource - ORG - Companies, agencies, institutions, etc.
# Ace Asphalt - PERSON - People, including fictional
# Ace Asphalt - PERSON - People, including fictional
#
#
#
# Colonial Life - ORG - Companies, agencies, institutions, etc.
# SALES REPRESENTATIVES - ORG - Companies, agencies, institutions, etc.
# Career Opportunities - PERSON - People, including fictional
# Colonial Life - ORG - Companies, agencies, institutions, etc.
# more than 70 years - DATE - Absolute or relative dates or periods
# first - ORDINAL - "first", "second", etc.
# first-year - DATE - Absolute or relative dates or periods
# 105,000 - MONEY - Monetary values, including unit
# last year - DATE - Absolute or relative dates or periods
# Earn - PERSON - People, including fictional
#
#
#
# Colonial Life - ORG - Companies, agencies, institutions, etc.
# SALES REPRESENTATIVES - ORG - Companies, agencies, institutions, etc.
# Career Opportunities - PERSON - People, including fictional
# Colonial Life - ORG - Companies, agencies, institutions, etc.
# more than 70 years - DATE - Absolute or relative dates or periods
# first - ORDINAL - "first", "second", etc.
# first-year - DATE - Absolute or relative dates or periods
# 105,000 - MONEY - Monetary values, including unit
# last year - DATE - Absolute or relative dates or periods
# Earn - PERSON - People, including fictional

# %%
for i in nlp_jd_k:
    for sent in i.sents:
        docx = nlp(sent.text)
        if docx.ents:
            displacy.render(docx, style='ent', jupyter=True)
#            doc, style='ent', options=options
        else:
            print(docx.text)
        print('\n')
    print('\n\n')
# Out:
# This Administrative Assistant position is responsible for performing a variety of clerical and administrative support functions in the areas of communications, data entry and retrieval, typing, filing, copying, and coordination of related administrative activities.
# <div class="entities" style="line-height: 2.5">JOB REQUIREMENTS:Attention to detailAbility to work in a fast paced environmentInvoicingProficient in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Word
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Excel
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     OutlookOther Administrative
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  responsibilities as needed.</div>
# QUALIFICATIONS:
# <div class="entities" style="line-height: 2.5">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     High School DiplomaAdministrative Assistant
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Experience1</div>
# <div class="entities" style="line-height: 2.5">-2
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Years
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  work experienceWorking knowledge of all basic office machines (fax, copier,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     10key
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     etc.)Strong
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  verbal and written communication
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     skillsStrong
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  work ethic.</div>
# ADMINISTRATIVE ASSISTANT Part Time
# <div class="entities" style="line-height: 2.5">The West Orange Healthcare District has a part time Administrative Assistant position to support the Executive Director and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     the Board of Trustees
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  by performing reception, secretarial, administrative and financial functions as needed.</div>
# <div class="entities" style="line-height: 2.5">Must have
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     3+ years
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  of related experience and be proficient in
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Microsoft Word
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ,
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Excel
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  and
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Power Point
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
# .</div>
# <div class="entities" style="line-height: 2.5">Some working knowledge of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     QuickBooks
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is a plus.</div>
# <div class="entities" style="line-height: 2.5">Send resume to:
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Kenneth.harker@healthcentral.org EOE Source - Orlando Sentinel
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </div>
# <div class="entities" style="line-height: 2.5">Administrative Assistant -  In Bus 26yrs Fashion
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Handbag
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  wholesaler need assistant for Sales and
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Inventory Depmts
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# .</div>
# , barnard@americanwest.cc
# <div class="entities" style="line-height: 2.5">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     SF52144As
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  leading supplier of handbags and accessories to
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     the Western Industry
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </div>
# <div class="entities" style="line-height: 2.5">,
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     American
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  West is looking for a detail orientated, focused self starter that can multi task in both a sales and operations environment.  </div>
# <div class="entities" style="line-height: 2.5">The Administrative assistant to sales and operations will be responsible for assistance in data entry and customer service for
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     the Sales Department
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and administrative assistance to
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     the New Product Development
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and Inventory manager; reporting to the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     EVP
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# .    </div>
# POSITION SUMMARY:
# <div class="entities" style="line-height: 2.5">The Sales and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Operations Administrative Assistant
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is responsible for assisting
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     the Sales Department
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     New Product Development
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and Inventory Manager with general administration duties, data entry and assisting customers with great customer service.    </div>
# JOB FUNCTIONS: ?
# <div class="entities" style="line-height: 2.5">Administrative assistance to
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     the Exec VP
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Sales Department
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Product Development
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and Inventory Manager  ?</div>
# Assist in answering incoming calls and forwarding them to the relevant parties.  ?
#
#
# Manage and execute internet sales and internet customer service.  ?
#
#
# Assist Territory sales managers with data entry.  ?
#
#
# Mailings of postcards, catalogs, flyers etc.  ?
# <div class="entities" style="line-height: 2.5">
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Daily
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  mailing and filing of invoices,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     weekly
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  mailing of independent rep invoices,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     two
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     weekly
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  account statement mailing.  ?</div>
# Office supply ordering  ?
# <div class="entities" style="line-height: 2.5">Assistant in
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     New Product Development
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Inventory Data
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  as needed ?</div>
# Cross training in other departments to assist in special projects outside of this position.  ?
#
#
# Attend and take notes for each sales meeting.
# <div class="entities" style="line-height: 2.5">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     ACCOUNTABILITY & RESPONSIBILITY
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#   ?</div>
# Take care of all our customers in a professional, friendly, ?exceed their expectation? and welcoming, manner.  ?
#
#
# Perform tasks in the most cost-effective, efficient and effective way possible with company culture and creed as guide.  ?
#
#
# Ensuring deadlines on specific tasks are met or extensions needed are clearly communicated.  ?
#
#
# Take ownership of position and assist other employees wherever and whenever possible. ?
#
#
# Be pro-active and ask for assistance when needed.  ?
#
#
# Be organized and pro-active with keeping and updating data and filing.
# <div class="entities" style="line-height: 2.5">Source - South
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Florida
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  Sun-Sentinel</div>
# Are you ready for something new?
#
#
# Are you tired of your current job and not making any real money?Complete Home Experts is looking for sales people who are tired of making average or below average money.
#
#
# If you want to make the great money you deserve, and change your lifestyle into what you want, then call us.
# <div class="entities" style="line-height: 2.5">We are filling
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     10
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  positions for
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     this quarter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .</div>
# <div class="entities" style="line-height: 2.5">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Excellent Customer Service
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is a must.</div>
# Attention to detail is a must.
#
#
# Our craftsmanship makes referrals easy!
# <div class="entities" style="line-height: 2.5">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Superior Staff Resources
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is currently seeking a
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Customer Service Representative/Cashier
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  for our client
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
# in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Albany
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     NY
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# . .</div>
# The successful candidate will be able to successfully perform the following duties: •
# <div class="entities" style="line-height: 2.5">The
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     CSR
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  processes cash, check and credit card payments in a walk-in environment in accordance with all documented guidelines.</div>
# <div class="entities" style="line-height: 2.5">•
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# </div>
# <div class="entities" style="line-height: 2.5">The
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     CSR
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is responsible for tag issuance and distribution at the window in accordance with all documented guidelines.</div>
# <div class="entities" style="line-height: 2.5">•
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# </div>
# <div class="entities" style="line-height: 2.5">The
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     CSR
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  processes new account applications in accordance with all documented guidelines.</div>
# <div class="entities" style="line-height: 2.5">•
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# </div>
# <div class="entities" style="line-height: 2.5">The
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     CSR
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is responsible for an end-of-
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     day
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  reconciliation of their
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     daily
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  work and submitting all relevant settlement documentation.</div>
# <div class="entities" style="line-height: 2.5">•
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# '</div>
# <div class="entities" style="line-height: 2.5">The
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     CSR
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is responsible for researching and resolving various customer disputes and inquires for which they have authority with the intention of satisfying all customer requests and resolving all customer disputes.</div>
# <div class="entities" style="line-height: 2.5">•
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# </div>
# <div class="entities" style="line-height: 2.5">The
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     CSR
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  performs appropriate
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Vector
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  transaction(s), completes corresponding outbound correspondence, and completes internal documentation and handoffs.•
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#              The CSR
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
#  is required to complete and submit all necessary documentation including, but not limited to production sheets,  batch headers, settlement sheets, refund requests and resolved folders on a
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     daily
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  basis.</div>
# <div class="entities" style="line-height: 2.5">•
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# </div>
# <div class="entities" style="line-height: 2.5">The
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     CSR
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is required to meet or exceed minimum standards for production and accuracy depending on
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     assignment.•
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#           </div>
# <div class="entities" style="line-height: 2.5">The
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     CSR
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  performs account/tag updates, financial account adjustments and handle cash in strict adherence to departmental policy and procedures•
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# </div>
# <div class="entities" style="line-height: 2.5">The
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     CSR
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is required to follow the direction of their
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Workleader
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  or
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Supervisor
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  regarding assignment,
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
# department policy and proceduresCandidates must successfully pass a 10-panel drug screening and background investigationMake a
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Superior
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
#  career choice
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     today
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .</div>
# www.superiorjobs.com.
# <div class="entities" style="line-height: 2.5">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     EOE M/F/D/V
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </div>
# <div class="entities" style="line-height: 2.5">The Opportunity:
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Schweitzer Engineering Laboratories
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     SEL
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) seeks a professional, innovative and detailed individual for our
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Customer Service Representative
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  position located in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Dothan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Alabama
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# .</div>
# If you are looking for an opportunity to bring your skills to a technically fast paced customer service oriented environment, this position is for you!
# <div class="entities" style="line-height: 2.5">
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Dothan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Alabama
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  is a rapidly growing city with a thriving community built around the landmarks of its past.</div>
# <div class="entities" style="line-height: 2.5">
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Dothan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  has become a melting pot for its friendly atmosphere of
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Southern Hospitality
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# .</div>
# <div class="entities" style="line-height: 2.5">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Customer Service
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  RepresentativeResponsibilities:    Support sales and marketing activities by maintaining regular contact with representatives/distributors and customers.     </div>
# Support field office staff.
#
#
# Collect, analyze and report customer feedback on products and services.
#
#
# Prepare bids and quotations, enter and track orders and monitor past due accounts.
#
#
# Promote product sales and track progress toward sales goals.
#
#
# Measure and ensure customer satisfaction.
#
#
# Plan and organize customer visits, conferences, seminars, training and other marketing and sales activities.
#
#
# Follow and improve customer service area processes.
# <div class="entities" style="line-height: 2.5">As a member of the Web and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Portal Development Team
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     the BHS Information Services Department
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Louisville
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     KY
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  the Java Developer- Intermediate designs, develops, and implements web-based
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Java
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  applications to support business requirements.  </div>
# Follows approved life cycle methodologies, creates design solutions and performs program coding and testing.
#
#
# Resolves technical issues through debugging, research, and investigation.
#
#
# Relies on extensive experience and judgment to plan and accomplish software development goals and user-required deliverables.
# <div class="entities" style="line-height: 2.5">Designs and develops high quality, scalable and robust solutions using
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Java
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Spring
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Hibernate
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , JSPs,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     XML
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  and/or
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     SQL
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  as well as other internal tools.  </div>
# <div class="entities" style="line-height: 2.5">Works with senior
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Java
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  developers, leads, web designers, project managers or database developers, to deliver a rich experience for users through a commissioning and deployable metadata system.</div>
# <div class="entities" style="line-height: 2.5">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#                             HSI & The Department of Commerce
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     DOC
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) is seeking to fill a short term approx.</div>
# <div class="entities" style="line-height: 2.5">(
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     6) month
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ...
# </mark>
#  and is expanding into
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     the Las Vegas
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  and southern
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Nevada
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  area.   </div>
# Ace offers extraordinary career potential and a great company culture.
# <div class="entities" style="line-height: 2.5">Applicants from the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Las Vegas
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  area only please.      </div>
# <div class="entities" style="line-height: 2.5">If you have the skills and contacts necessary and want to build your own success story with an industry leader, please e-mail your resume to us
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     ASAP
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
# !!        </div>
# <div class="entities" style="line-height: 2.5">Contact
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Ace Asphalt
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#   </div>
# E-mail your resume, cover letter and salary history to:    Ace Asphalt Account Executive Position
#
#
# careers@aceasphalt.com
#
#
# In addition, you may contact us directly by phone at the number below.
# <div class="entities" style="line-height: 2.5">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Jeff BohneHuman Resource
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  Director602-304-4080    </div>
# <div class="entities" style="line-height: 2.5">For more information about
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Ace Asphalt
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , check out our website at –   www.aceasphalt.com    </div>
# <div class="entities" style="line-height: 2.5">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Ace Asphalt
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  is an equal opportunity employer  </div>
# Why settle for an ordinary sales career, when you can put more life in your career with us?
# <div class="entities" style="line-height: 2.5">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Colonial Life
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  has an immediate opening for
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     SALES REPRESENTATIVES
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  to join our growing team.</div>
# We are a leader in worksite marketing.
#
#
# We work with employers and their employees to provide benefit solutions in one neat package: benefits communication, enrollment, and personal insurance products.
#
#
# Skills/backgrounds associated with success are:    Experience attaining challenging sales goals.
#
#
# Ability to identify and prioritize sales opportunities.
#
#
# Effective verbal and written communication skills, and ability to successfully engage all levels of customer base.
#
#
# Self-motivation and drive; willing to invest time in developing client relationships.
# <div class="entities" style="line-height: 2.5">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Career Opportunities
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# :     Prospect, market and deliver benefit communications and enrollment solutions to decision makers.    </div>
# Present voluntary product solutions to employees.
#
#
# We provide the tools, training and support to help you succeed.
# <div class="entities" style="line-height: 2.5">With
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Colonial Life
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , you can:      </div>
# Achieve more than just sales – enjoy being a benefits counselor.
# <div class="entities" style="line-height: 2.5">Work with a sound company that’s had a solid history of integrity and growth for
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     more than 70 years
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .    </div>
# <div class="entities" style="line-height: 2.5">Enjoy strong earnings potential, even in your
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     first year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , plus competitive bonuses and incentives.</div>
# <div class="entities" style="line-height: 2.5">Average
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     first-year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  income for our top new benefit counselors hit $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     105,000
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     last year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .     </div>
# Grow and refine your skills through our proven phone prospecting system and structured sales training program.
#
#
# Enjoy a flexible work schedule.
# <div class="entities" style="line-height: 2.5">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Earn
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  what you’re worth, help people, and have fun doing it!</div>
# Why settle for an ordinary sales career, when you can put more life in your career with us?
# <div class="entities" style="line-height: 2.5">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Colonial Life
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  has an immediate opening for
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     SALES REPRESENTATIVES
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  to join our growing team.</div>
# We are a leader in worksite marketing.
#
#
# We work with employers and their employees to provide benefit solutions in one neat package: benefits communication, enrollment, and personal insurance products.
#
#
# Skills/backgrounds associated with success are:    Experience attaining challenging sales goals.
#
#
# Ability to identify and prioritize sales opportunities.
#
#
# Effective verbal and written communication skills, and ability to successfully engage all levels of customer base.
#
#
# Self-motivation and drive; willing to invest time in developing client relationships.
# <div class="entities" style="line-height: 2.5">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Career Opportunities
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# :     Prospect, market and deliver benefit communications and enrollment solutions to decision makers.    </div>
# Present voluntary product solutions to employees.
#
#
# We provide the tools, training and support to help you succeed.
# <div class="entities" style="line-height: 2.5">With
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Colonial Life
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , you can:      </div>
# Achieve more than just sales – enjoy being a benefits counselor.
# <div class="entities" style="line-height: 2.5">Work with a sound company that’s had a solid history of integrity and growth for
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     more than 70 years
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .    </div>
# <div class="entities" style="line-height: 2.5">Enjoy strong earnings potential, even in your
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     first year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , plus competitive bonuses and incentives.</div>
# <div class="entities" style="line-height: 2.5">Average
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     first-year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  income for our top new benefit counselors hit $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     105,000
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     last year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .     </div>
# Grow and refine your skills through our proven phone prospecting system and structured sales training program.
#
#
# Enjoy a flexible work schedule.
# <div class="entities" style="line-height: 2.5">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Earn
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  what you’re worth, help people, and have fun doing it!</div>

# %%
import warnings
warnings.filterwarnings('ignore')
#warnings.filterwarnings(action='once')

# %% [markdown]
# ## Pre-processing using skicit-learn and Visualisation Libraries

# %%
from time import time
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import NMF, LatentDirichletAllocation
import pyLDAvis.sklearn
from pylab import bone, pcolor, colorbar, plot, show, rcParams, savefig

# %% [markdown]
# #### Configuration

# %%
# Number of points to use from Dataset
n_samples = 5000

# Number of features from vectorised featureset
n_features = 5000

# Number of Topics to extract
n_components = 10

# Number of Words per topic
n_top_words = 15

# %% [markdown]
# #### Use Count Vectorizer for extracting features

# %%
tf_vectorizer = CountVectorizer(max_df=0.90, min_df=10, max_features=n_features, stop_words='english')
# Out:
# /home/etzimopoulos/anaconda3/envs/nlp_course/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
tf = tf_vectorizer.fit_transform(k_jobs['Job Description'][:n_samples])
# Out:
# /home/etzimopoulos/anaconda3/envs/nlp_course/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
tf
# Out:
# /home/etzimopoulos/anaconda3/envs/nlp_course/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <5000x3365 sparse matrix of type '<class 'numpy.int64'>'
# 	with 547834 stored elements in Compressed Sparse Row format>

# %% [markdown]
# #### Use Tf-IDF Vectorizer for extracting features

# %%
tfidf_vectorizer = TfidfVectorizer(max_df=0.90, min_df=10, max_features=n_features, stop_words='english')
# Out:
# /home/etzimopoulos/anaconda3/envs/nlp_course/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
tfidf = tfidf_vectorizer.fit_transform(k_jobs['Job Description'][:n_samples])
# Out:
# /home/etzimopoulos/anaconda3/envs/nlp_course/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
tfidf
# Out:
# /home/etzimopoulos/anaconda3/envs/nlp_course/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <5000x3365 sparse matrix of type '<class 'numpy.float64'>'
# 	with 547834 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ## LDA modelling

# %% [markdown]
# #### Kaggle Job Descriptions

# %%
LDA = LatentDirichletAllocation(n_components=n_components, max_iter=5,
                                learning_method='online',
                                learning_offset=50.,
                                random_state=0)
# Out:
# /home/etzimopoulos/anaconda3/envs/nlp_course/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Fit document using Bag of Words (Term Frequency)
LDA1 = LDA.fit(tf)
# Out:
# /home/etzimopoulos/anaconda3/envs/nlp_course/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Fit again using Inverse Document Frequency (TFIDF)
LDA2 = LDA.fit(tfidf)

# %%
# Check features length
len(tf_vectorizer.get_feature_names())
# Out:
# /home/etzimopoulos/anaconda3/envs/nlp_course/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 4831

# %%
# Check vectors length
len(tfidf_vectorizer.get_feature_names())
# Out:
# /home/etzimopoulos/anaconda3/envs/nlp_course/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 3365

# %%
import random
# Out:
# /home/etzimopoulos/anaconda3/envs/nlp_course/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
for i in range(10):
    random_word_id = random.randint(0,n_features)
    print(tf_vectorizer.get_feature_names()[random_word_id])
# Out:
# fl
# million
# professionalour
# easily
# dental
# actuals
# compliance
# gap
# homes
# invest
# /home/etzimopoulos/anaconda3/envs/nlp_course/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# #### Check number of components

# %%
len(LDA1.components_)
# Out:
# /home/etzimopoulos/anaconda3/envs/nlp_course/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 10

# %%
len(LDA2.components_)
# Out:
# /home/etzimopoulos/anaconda3/envs/nlp_course/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 10

# %% [markdown]
# ### Top 10 words per topic Using Bag of Words (TF - Document Term Frequency)

# %%
for index,topic in enumerate(LDA.components_):
    print(f'THE TOP {n_top_words} WORDS FOR TOPIC #{index}')
    print([tf_vectorizer.get_feature_names()[i] for i in topic.argsort()[-n_top_words:]])
    print('\n')
# Out:
# /home/etzimopoulos/anaconda3/envs/nlp_course/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# THE TOP 15 WORDS FOR TOPIC #0
# ['oriented', 'guidance', 'industries', 'cedar', 'location', 'locate', 'expanding', 'introduce', 'mn', 'maintains', 'monitors', 'located', 'onboard', 'objective', 'participates']
#
#
# THE TOP 15 WORDS FOR TOPIC #1
# ['notes', 'cleanliness', '8pm', 'cutco', 'escalated', '85', 'partnered', 'clear', 'impacting', 'honestly', 'ipafamily', 'assets', 'correct', 'follow', 'master']
#
#
# THE TOP 15 WORDS FOR TOPIC #2
# ['creation', 'fastest', 'box', 'firm', 'mix', 'accruals', 'participates', 'paperwork', 'cutco', 'investments', 'mailings', 'master', 'notes', 'prestigious', 'disciplinary']
#
#
# THE TOP 15 WORDS FOR TOPIC #3
# ['mcdonald', 'enrollment', 'michigan', 'debt', 'market', 'ask', 'experis', 'postage', 'divisional', 'certain', 'arrival', 'macros', 'modification', 'childcare', 'appraising']
#
#
# THE TOP 15 WORDS FOR TOPIC #4
# ['origin', 'patients', 'flows', 'enabled', 'flow', 'priority', 'branches', 'mechanical', 'desired', 'operator', 'experience', 'hardworking', 'integrates', 'extensive', 'oriented']
#
#
# THE TOP 15 WORDS FOR TOPIC #5
# ['ip', 'agile', 'implications', 'assets', 'pipe', 'clarification', 'clinicians', 'issuing', 'peak', 'cooperation', 'deductions', 'cross', 'ipafamily', 'crm', 'families']
#
#
# THE TOP 15 WORDS FOR TOPIC #6
# ['heart', 'implementations', 'modeling', 'price', 'cleanliness', 'hearted', 'paperwork', 'outages', 'desirable', 'gm', 'assets', 'features', 'attend', 'master', 'act']
#
#
# THE TOP 15 WORDS FOR TOPIC #7
# ['miles', 'outpatient', 'enthusiastic', 'cancellations', 'latest', 'children', 'immediate', 'outages', 'cleanliness', 'notes', 'gained', 'mailings', 'master', 'clear', 'families']
#
#
# THE TOP 15 WORDS FOR TOPIC #8
# ['ipafamily', 'heard', 'controllers', 'architectures', 'escrow', 'evaluated', 'exec', 'career', 'hearing', 'evaluating', 'desirable', 'conflicting', 'bonus', 'bas', 'firms']
#
#
# THE TOP 15 WORDS FOR TOPIC #9
# ['geography', 'onboard', 'patrons', 'accrued', 'corp', 'cedar', '90', 'acts', 'corrections', 'mn', 'located', 'fitting', 'guidance', 'intangible', 'participates']

# %%
pyLDAvis.enable_notebook()
dash = pyLDAvis.sklearn.prepare(LDA2, tfidf, tf_vectorizer, mds='tsne')
dash
# Out:
# /home/etzimopoulos/anaconda3/envs/nlp_course/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-163-473035dc09bd> in <module>
#       1 pyLDAvis.enable_notebook()
# ----> 2 dash = pyLDAvis.sklearn.prepare(LDA2, tfidf, tf_vectorizer, mds='tsne')
#       3 dash
#
# ~/anaconda3/envs/nlp_course/lib/python3.7/site-packages/pyLDAvis/sklearn.py in prepare(lda_model, dtm, vectorizer, **kwargs)
#      92     See `pyLDAvis.prepare` for **kwargs.
#      93     """
# ---> 94     opts = fp.merge(_extract_data(lda_model, dtm, vectorizer), kwargs)
#      95     return pyLDAvis.prepare(**opts)
#
# ~/anaconda3/envs/nlp_course/lib/python3.7/site-packages/pyLDAvis/sklearn.py in _extract_data(lda_model, dtm, vectorizer)
#      43     assert term_freqs.shape[0] == len(vocab), \
#      44         ('Term frequencies and vocabulary are of different sizes, {} != {}.'
# ---> 45          .format(term_freqs.shape[0], len(vocab)))
#      46
#      47     assert topic_term_dists.shape[1] == dtm.shape[1], \
#
# AssertionError: Term frequencies and vocabulary are of different sizes, 3365 != 4831.

# %% [markdown]
# ### Top 10 words per topic Using TFIDF

# %%
for index,topic in enumerate(LDA2.components_):
    print(f'THE TOP {n_top_words} WORDS FOR TOPIC #{index}')
    print([tfidf_vectorizer.get_feature_names()[i] for i in topic.argsort()[-n_top_words:]])
    print('\n')
# Out:
# THE TOP 15 WORDS FOR TOPIC #0
# ['tax', 'offclosed', 'plan401k', 'contributionflexible', 'requiredtitlemax', 'requiredleadership', 'lawseffectively', 'proceduresability', 'skillsminimum', 'retentionmanage', 'sourcesdetermine', 'requiredproficiency', 'sundayscompany', 'structuregroup', 'tmx']
#
#
# THE TOP 15 WORDS FOR TOPIC #1
# ['store', 'customer', 'accounting', 'experience', 'inventory', 'accountant', 'tools', 'customers', 'payment', 'outside', 'project', 'business', 'equipment', 'matco', 'sales']
#
#
# THE TOP 15 WORDS FOR TOPIC #2
# ['excellent', 'locations', 'communication', 'management', 'skills', 'advancement', 'tmx', 'time', 'experience', 'products', 'retail', 'sales', 'store', 'wireless', 'gowireless']
#
#
# THE TOP 15 WORDS FOR TOPIC #3
# ['schedulesemployment', 'insuranceemployee', 'sexual', 'fact', 'row', 'bred', 'lebanon', 'voted', 'hardworking', 'cooked', 'born', 'restaurant', 'solely', 'cracker', 'barrel']
#
#
# THE TOP 15 WORDS FOR TOPIC #4
# ['taxes', 'training', 'marketing', 'industry', 'market', 'year', 'community', 'seasonal', 'franchisees', 'support', 'learn', 'ongoing', 'preparation', 'liberty', 'tax']
#
#
# THE TOP 15 WORDS FOR TOPIC #5
# ['progress', 'arrangements', 'performance', 'business', 'use', 'csr', 'day', 'promotions', 'travel', 'enterprise', 'far', 'executives', 'project', 'executive', 'll']
#
#
# THE TOP 15 WORDS FOR TOPIC #6
# ['opportunities', 'people', 'snap', 'work', 'customer', 'opportunity', 'time', 'team', 'franchise', 'need', 'business', 'looking', 'career', 'sales', 'aflac']
#
#
# THE TOP 15 WORDS FOR TOPIC #7
# ['shine', 'technology', 'interactive', 'connected', 'really', 'create', 'pay', 'team', 'customer', 'store', 'mobile', 'retail', 'sales', 'customers', 'll']
#
#
# THE TOP 15 WORDS FOR TOPIC #8
# ['project', 'operations', 'engineer', 'bilingual', 'investment', 'jani', 'king', 'construction', 'operator', 'janitorial', 'franchise', 'driver', 'commercial', 'cleaning', 'manager']
#
#
# THE TOP 15 WORDS FOR TOPIC #9
# ['mvrvalid', 'sundayscompany', 'trainingaccelerated', 'advancementessential', 'environmentstrong', 'contributionflexible', 'accountpaid', 'ageuse', 'equityauto', 'skillsminimum', 'requiredproficiency', 'mannerspecific', 'offclosed', 'preferredretail', 'tmx']

# %%
#pyLDAvis.enable_notebook()
#dash = pyLDAvis.sklearn.prepare(LDA2, tfidf, tfidf_vectorizer, mds='tsne')
#dash

# %% [markdown]
# ## NMF modelling

# %% [markdown]
# ##### Fit NMF Model  - Frobenius norm

# %%
# Fit the NMF model
print("Fitting the NMF model (Frobenius norm) with tf-idf features, "
      "n_samples=%d and n_features=%d..."
      % (n_samples, n_features))
t0 = time()
nmf = NMF(n_components=n_components, random_state=1,
          alpha=.1, l1_ratio=.5).fit(tfidf)
print("done in %0.3fs." % (time() - t0))

print("\nTopics in NMF model (Frobenius norm):")
tfidf_feature_names = tfidf_vectorizer.get_feature_names()
sf.print_top_words(nmf, tfidf_feature_names, n_top_words)
# Out:
# Fitting the NMF model (Frobenius norm) with tf-idf features, n_samples=5000 and n_features=1000...
# done in 0.940s.
#
# Topics in NMF model (Frobenius norm):
#
# The top 8 words for topic #0 are:sales customer gowireless retail wireless experience ll store
#
# The top 8 words for topic #1 are:tax liberty preparation ongoing learn support franchisees seasonal
#
# The top 8 words for topic #2 are:franchise matco sales business tools equipment snap outside
#
# The top 8 words for topic #3 are:vector time regular opportunities income looking growing need
#
# The top 8 words for topic #4 are:aflac career sales programs nation need representative insurance

# %% [markdown]
# ##### Fit NMF Model  - Generalized Kullback-Leibler divergence

# %%
# Fit the NMF model
print("Fitting the NMF model (generalized Kullback-Leibler divergence) with "
      "tf-idf features, n_samples=%d and n_features=%d..."
      % (n_samples, n_features))
t0 = time()
nmf = NMF(n_components=n_components, random_state=1,
          beta_loss='kullback-leibler', solver='mu', max_iter=1000, alpha=.1,
          l1_ratio=.5).fit(tfidf)
print("done in %0.3fs." % (time() - t0))

print("\nTopics in NMF model (generalized Kullback-Leibler divergence):")

# User TFIDF vectorizer
tfidf_feature_names = tfidf_vectorizer.get_feature_names()

# Print top words
sf.print_top_words(nmf, tfidf_feature_names, n_top_words)
# Out:
# Fitting the NMF model (generalized Kullback-Leibler divergence) with tf-idf features, n_samples=5000 and n_features=1000...
# done in 2.291s.
#
# Topics in NMF model (generalized Kullback-Leibler divergence):
#
# The top 8 words for topic #0 are:customer sales experience skills team service work services
#
# The top 8 words for topic #1 are:tax liberty preparation ongoing learn support franchisees seasonal
#
# The top 8 words for topic #2 are:sales matco payment equipment outside central business tools
#
# The top 8 words for topic #3 are:franchise business snap manager time income looking vector
#
# The top 8 words for topic #4 are:aflac career sales programs nation insurance representative need

# %% [markdown]
# ### LDA

# %% [markdown]
# ##### Fit Model with TF (DTM) vectorizer

# %%
print("Fitting LDA models with tf features, "
      "n_samples=%d and n_features=%d..."
      % (n_samples, n_features))
lda = LatentDirichletAllocation(n_components=n_components, max_iter=5,
                                learning_method='online',
                                learning_offset=50.,
                                random_state=0)
t0 = time()
# Fit using TF vectorizer
lda.fit(tf)
print("done in %0.3fs." % (time() - t0))

print("\nTopics in LDA model:")
tf_feature_names = tf_vectorizer.get_feature_names()
sf.print_top_words(lda, tf_feature_names, n_top_words)
# Out:
# Fitting LDA models with tf features, n_samples=5000 and n_features=1000...
# done in 5.586s.
#
# Topics in LDA model:
#
# The top 8 words for topic #0 are:sales business work aflac career tools opportunity need
#
# The top 8 words for topic #1 are:sales experience skills gowireless wireless required management years
#
# The top 8 words for topic #2 are:customer manager sales service management team business customers
#
# The top 8 words for topic #3 are:liberty tax sales support learn marketing preparation ongoing
#
# The top 8 words for topic #4 are:opportunities time training growing including looking year work

# %%
#pyLDAvis.enable_notebook()
#dash = pyLDAvis.sklearn.prepare(lda, tf, tf_vectorizer, mds='tsne')
#dash

# %% [markdown]
# #### Fit Model with TfIDF vectorizer

# %%
print("Fitting LDA models with tf features, "
      "n_samples=%d and n_features=%d..."
      % (n_samples, n_features))
lda = LatentDirichletAllocation(n_components=n_components, max_iter=5,
                                learning_method='online',
                                learning_offset=50.,
                                random_state=0)
t0 = time()

# Fit using TFIDF vectorizer
lda.fit(tfidf)
print("done in %0.3fs." % (time() - t0))

print("\nTopics in LDA model:")
tfidf_feature_names = tfidf_vectorizer.get_feature_names()
sf.print_top_words(lda, tfidf_feature_names, n_top_words)
# Out:
# Fitting LDA models with tf features, n_samples=5000 and n_features=1000...
# done in 3.376s.
#
# Topics in LDA model:
#
# The top 8 words for topic #0 are:manager retail sales ll store customers cleaning customer
#
# The top 8 words for topic #1 are:sales aflac matco outside equipment payment career business
#
# The top 8 words for topic #2 are:tax liberty customer project experience support company skills
#
# The top 8 words for topic #3 are:gowireless wireless store retail sales products advancement locations
#
# The top 8 words for topic #4 are:franchise business snap looking vector management time training

# %%
#pyLDAvis.enable_notebook()
#dash = pyLDAvis.sklearn.prepare(lda, tfidf, tfidf_vectorizer, mds='tsne')
#dash

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Credits and References</b>
#
# This notebook has leveraged work from the following authors and adjusted it accordingly to fit the specific dataset under BSD 3 Clause License:
#
#
# **Authors**
# * Olivier Grisel olivier.grisel@ensta.org
# * Lars Buitinck
# * Chyi-Kwei Yau chyikwei.yau@gmail.com>
# * License: BSD 3 clause
#
# See link below for full Example of their work:
#
# https://scikit-learn.org/stable/auto_examples/applications/plot_topics_extraction_with_nmf_lda.html#sphx-glr-auto-examples-applications-plot-topics-extraction-with-nmf-lda-py
#
#
# </div>

# %% [markdown]
# ### Map topic in dataframe for Job Description

# %%
k_jobs['Job Description'][0]
# Out:
# 'This Administrative Assistant position is responsible for performing a variety of clerical and administrative support functions in the areas of communications, data entry and retrieval, typing, filing, copying, and coordination of related administrative activities. JOB REQUIREMENTS:Attention to detailAbility to work in a fast paced environmentInvoicingProficient in Word, Excel and OutlookOther Administrative responsibilities as needed.QUALIFICATIONS:High School DiplomaAdministrative Assistant Experience1-2 Years work experienceWorking knowledge of all basic office machines (fax, copier, 10key, etc.)Strong verbal and written communication skillsStrong work ethic.'

# %%
# Topic distribution for Job[0] rounded to three decimal points
topic_results = lda.transform(tf).round(3)

# %%
k_jobs['Job Description'][6]
# Out:
# 'As a member of the Web and Portal Development Team of the BHS Information Services Department in Louisville, KY the Java Developer- Intermediate designs, develops, and implements web-based Java applications to support business requirements.  Follows approved life cycle methodologies, creates design solutions and performs program coding and testing.  Resolves technical issues through debugging, research, and investigation.  Relies on extensive experience and judgment to plan and accomplish software development goals and user-required deliverables.  Designs and develops high quality, scalable and robust solutions using Java, Spring, Hibernate, JSPs, XML and/or SQL as well as other internal tools.  Works with senior Java developers, leads, web designers, project managers or database developers, to deliver a rich experience for users through a commissioning and deployable metadata system.'

# %%
topic_results[6]
# Out:
# array([0.004, 0.004, 0.983, 0.004, 0.004])

# %%
# Get index position of highest probability
topic_results[0].argmax()
# Out:
# 2

# %%
# Create a new copy of the original dataframe with only the N Samples modelling took place for
modelled_k_jobs = k_jobs.iloc[0:n_samples].copy()

# %%
modelled_k_jobs.head()
# Out:
#   Location       Company                        Job Title  \
# 0                   None         Administrative Assistant
# 1                                Administrative Assistant
# 2           americanwest         Administrative Assistant
# 3                   None             Sales Representative
# 4                   None  Customer Service Representative
#
#                                      Job Description Salary  \
# 0  This Administrative Assistant position is resp...
# 1  ADMINISTRATIVE ASSISTANT Part Time The West Or...
# 2  Administrative Assistant -  In Bus 26yrs Fashi...
# 3  Are you ready for something new? Are you tired...
# 4  Superior Staff Resources is currently seeking ...
#
#                              E-mail
# 0
# 1  Kenneth.harker@healthcentral.org
# 2           barnard@americanwest.cc
# 3
# 4

# %%
# Map model topics to N Samples
modelled_k_jobs['Topic'] = topic_results.argmax(axis=1)

# %%
modelled_k_jobs.head(50)
# Out:
#    Location         Company                        Job Title  \
# 0                      None         Administrative Assistant
# 1                                   Administrative Assistant
# 2              americanwest         Administrative Assistant
# 3                      None             Sales Representative
# 4                      None  Customer Service Representative
# 5                      None  Customer Service Representative
# 6                      None                   Java Developer
# 7                      None                   Java Developer
# 8                      None         Administrative Assistant
# 9                      None                Financial Analyst
# 10                     None                  Project Manager
# 11                     None                   Java Developer
# 12                     None             Sales Representative
# 13                     None                  Project Manager
# 14                                       Executive Assistant
# 15                     None              Executive Assistant
# 16                     None           Maintenance Technician
# 17                     None         Administrative Assistant
# 18                     None                Financial Analyst
# 19                     None           Maintenance Technician
# 20                     None                  Project Manager
# 21                     None                  Project Manager
# 22                     None                  Project Manager
# 23                     None                  Project Manager
# 24                     None         Administrative Assistant
# 25                     None                  Project Manager
# 26                     None               Physical Therapist
# 27                     None              Executive Assistant
# 28                     None                    Store Manager
# 29                     None             Sales Representative
# 30                     None             Sales Representative
# 31           selectstaffing                 Staff Accountant
# 32                     None             Sales Representative
# 33                     None             Sales Representative
# 34                     None         Administrative Assistant
# 35                     None      Inside Sales Representative
# 36                     None              Executive Assistant
# 37                     None           Maintenance Technician
# 38                     None              Executive Assistant
# 39                     None                Account Executive
# 40                     None                  Project Manager
# 41                     None                     Receptionist
# 42                     None  Customer Service Representative
# 43                     None                Senior Accountant
# 44                     None                Senior Accountant
# 45                     None                Senior Accountant
# 46                     None             Sales Representative
# 47                     None                Account Executive
# 48            SandCompanies                     Receptionist
# 49                     None             Sales Representative
#
#                                       Job Description Salary  \
# 0   This Administrative Assistant position is resp...
# 1   ADMINISTRATIVE ASSISTANT Part Time The West Or...
# 2   Administrative Assistant -  In Bus 26yrs Fashi...
# 3   Are you ready for something new? Are you tired...
# 4   Superior Staff Resources is currently seeking ...
# 5   The Opportunity:Schweitzer Engineering Laborat...
# 6   As a member of the Web and Portal Development ...
# 7                           HSI & The Department o...
# 8   The main function of this role is to provide a...
# 9   Financial Analyst Perform portfolio analysis, ...
# 10  Project Manager The Project Manager will plan ...
# 11  Application Developer-Senior-JavaSummary:This ...
# 12  GC Services, a top performer in the Teleservic...
# 13  Mosaic Sales Solutions is a full-service marke...
# 14  Executive AssistantAdams Produce Company, a 11...
# 15  Management Executives of a growing healthcare ...
# 16  Sonoco Products      - Direct Hire -      Main...
# 17  Cookeville Regional Medical Center is seeking ...
# 18  As our Manager FP&A based in  CA, you will be ...
# 19  JOB NAME:  MAINTENANCE TECHNICIAN JOB DESCRIPT...
# 20  Project Manager Job  An Engineering & Construc...
# 21  Project Manager Job  An energy company is look...
# 22  Project Manager Job  National Power Systems co...
# 23  Project Manager Job  Immediate need for a PROJ...
# 24  At APS Healthcare, we are passionate about cha...
# 25  Navistar International Corporation is a holdin...
# 26  Facility:   Saint Luke's Home Care & HospiceDe...
# 27  This position provides administrative support ...
# 28  Are you the type of person that wants to be ch...
# 29  SALES REPRESENTATIVEAre you hungry to make tha...
# 30  SALES REPRESENTATIVEAre you hungry to make tha...
# 31  Staff Accountant If you are an experienced Sta...
# 32  SALES REPRESENTATIVEAre you hungry to make tha...
# 33  SALES REPRESENTATIVEAre you hungry to make tha...
# 34  ADMINISTRATIVE ASSISTANTJob Description: Provi...
# 35  American West Worldwide Express, a leader in t...
# 36   POSITION OBJECTIVE:   The Executive Assistant...
# 37  Are you looking for a challenging job where yo...
# 38  Long term and short term Executive Assistant p...
# 39  Account Executive- Outside Sales Muzak, The #1...
# 40  The Account Development Project Manager (PM) i...
# 41  To assist all departments in the dealership in...
# 42  At  Alvin Magnon Jewelers, Inc. we take pride ...
# 43          Seeking Internal Senior Accoutant for ...
# 44      JOIN THE BOYDS TEAM!  Senior Accountant  C...
# 45  Our client, a privately held, well established...
# 46  United Subcontractors, Inc., a leader in the C...
# 47  The Affiliate Services Account Executive serve...
# 48  Receptionist Sand Companies, Inc. is seeking a...
# 49  -Will sell dialysis access products to hospita...
#
#                                   E-mail  Topic
# 0                                             2
# 1       Kenneth.harker@healthcentral.org      2
# 2                barnard@americanwest.cc      2
# 3                                             2
# 4                                             2
# 5                                             2
# 6                                             2
# 7                                             2
# 8                                             2
# 9                                             2
# 10                                            2
# 11                                            2
# 12                                            2
# 13                                            2
# 14  maryellen.mattison@adamsproduce.com.      2
# 15                                            2
# 16                                            2
# 17                                            2
# 18                                            2
# 19                                            2
# 20                                            2
# 21                                            2
# 22                                            2
# 23                                            2
# 24                                            2
# 25                                            2
# 26                                            2
# 27                                            2
# 28                                            2
# 29                                            2
# 30                                            2
# 31                ib3@selectstaffing.com      2
# 32                                            2
# 33                                            2
# 34                                            2
# 35                                            2
# 36                                            2
# 37                                            2
# 38                                            2
# 39                                            2
# 40                                            2
# 41                                            2
# 42                                            2
# 43                                            2
# 44                                            2
# 45                                            2
# 46                                            2
# 47                                            2
# 48                  HR@SandCompanies.com      2
# 49                                            1

# %%
test_topics = sf.return_top_words(lda, tfidf_feature_names, n_top_words)
test_topics
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-51-6c2e0aafec74> in <module>
# ----> 1 test_topics = sf.return_top_words(lda, tfidf_feature_names, n_top_words)
#       2 test_topics
#
# /mnt/c/Users/etzim/Google Drive/Career/Data Science/GitHub/nlp-job-skills-topic-modelling/support_functions.py in return_top_words(model, feature_names, n_top_words)
#      84     t_topics = []
#      85     for topic_idx, topic in enumerate(model.components_):
# ---> 86         t_topics[topic_idx].append([feature_names[i] for i in topic.argsort()[:-n_top_words - 1:-1]])
#      87     top_topics = pd.DataFrame(t_topics)
#      88     return top_topics
#
# IndexError: list index out of range

# %%
t_topics = []
for index,topic in enumerate(LDA2.components_):
    t_topics.append([tfidf_vectorizer.get_feature_names()[i] for i in topic.argsort()[-n_top_words:]])

# %%
print(t_topics[0])
# Out:
# ['customer', 'cleaning', 'customers', 'store', 'll', 'sales', 'retail', 'manager']

# %%
t_topics
# Out:
# [['customer',
#   'cleaning',
#   'customers',
#   'store',
#   'll',
#   'sales',
#   'retail',
#   'manager'],
#  ['business',
#   'career',
#   'payment',
#   'equipment',
#   'outside',
#   'matco',
#   'aflac',
#   'sales'],
#  ['skills',
#   'company',
#   'support',
#   'experience',
#   'project',
#   'customer',
#   'liberty',
#   'tax'],
#  ['locations',
#   'advancement',
#   'products',
#   'sales',
#   'retail',
#   'store',
#   'wireless',
#   'gowireless'],
#  ['training',
#   'time',
#   'management',
#   'vector',
#   'looking',
#   'snap',
#   'business',
#   'franchise']]

# %%
top_topics = pd.DataFrame(t_topics)

# %%
top_topics
# Out:
#            0            1           2           3        4         5  \
# 0   customer     cleaning   customers       store       ll     sales
# 1   business       career     payment   equipment  outside     matco
# 2     skills      company     support  experience  project  customer
# 3  locations  advancement    products       sales   retail     store
# 4   training         time  management      vector  looking      snap
#
#           6           7
# 0    retail     manager
# 1     aflac       sales
# 2   liberty         tax
# 3  wireless  gowireless
# 4  business   franchise

# %%
#df_topic_keywords = pd.DataFrame(topic_keywords)
top_topics.columns = ['Word '+str(i) for i in range(top_topics.shape[1])]
top_topics.index = ['Topic '+str(i) for i in range(top_topics.shape[0])]
top_topics
# Out:
#             Word 0       Word 1      Word 2      Word 3   Word 4    Word 5  \
# Topic 0   customer     cleaning   customers       store       ll     sales
# Topic 1   business       career     payment   equipment  outside     matco
# Topic 2     skills      company     support  experience  project  customer
# Topic 3  locations  advancement    products       sales   retail     store
# Topic 4   training         time  management      vector  looking      snap
#
#            Word 6      Word 7
# Topic 0    retail     manager
# Topic 1     aflac       sales
# Topic 2   liberty         tax
# Topic 3  wireless  gowireless
# Topic 4  business   franchise

# %%
pp

# %% [markdown]
# ### Predict topic for Unseen Job Description
