# %% [markdown]
# # Topic Modelling using NLP - Job Descriptions Data

# %% [markdown]
# ## Part 2 - EDA, Feature extraction and Topic Modelling using NLP

# %%
import pandas as pd
import support_functions as sf

# %% [markdown]
# ### Load Kaggle dataset

# %%
k_jobs = pd.read_csv('../offline-datasets/kaggle-top30-job-descriptions/pre-processed/KaggleJobs.csv', na_filter=False)

# %%
k_jobs.head()
# Out:
#    Unnamed: 0 Location       Company                        Job Title  \
# 0           0                   None         Administrative Assistant
# 1           1                                Administrative Assistant
# 2           2           americanwest         Administrative Assistant
# 3           3                   None             Sales Representative
# 4           4                   None  Customer Service Representative
#
#                                      Job Description Salary  \
# 0  This Administrative Assistant position is resp...
# 1  ADMINISTRATIVE ASSISTANT Part Time The West Or...
# 2  Administrative Assistant -  In Bus 26yrs Fashi...
# 3  Are you ready for something new? Are you tired...
# 4  Superior Staff Resources is currently seeking ...
#
#                              E-mail
# 0
# 1  Kenneth.harker@healthcentral.org
# 2           barnard@americanwest.cc
# 3
# 4

# %%
# Drop 1st column
k_jobs.drop('Unnamed: 0', axis=1, inplace=True)

# %%
k_jobs.head(10)
# Out:
#   Location       Company                        Job Title  \
# 0                   None         Administrative Assistant
# 1                                Administrative Assistant
# 2           americanwest         Administrative Assistant
# 3                   None             Sales Representative
# 4                   None  Customer Service Representative
# 5                   None  Customer Service Representative
# 6                   None                   Java Developer
# 7                   None                   Java Developer
# 8                   None         Administrative Assistant
# 9                   None                Financial Analyst
#
#                                      Job Description Salary  \
# 0  This Administrative Assistant position is resp...
# 1  ADMINISTRATIVE ASSISTANT Part Time The West Or...
# 2  Administrative Assistant -  In Bus 26yrs Fashi...
# 3  Are you ready for something new? Are you tired...
# ...

# %%
k_jobs['Job Description'][6]
# Out:
# '<P><STRONG>As a member of the Web and Portal Development Team of the BHS Information Services Department in Louisville, KY the Java Developer- Intermediate designs, develops, and implements web-based Java applications to support business requirements.</STRONG>\xa0 Follows approved life cycle methodologies, creates design solutions and performs program coding and testing.\xa0 Resolves technical issues through debugging, research, and investigation.\xa0 Relies on extensive experience and judgment to plan and accomplish software development goals and user-required deliverables.\xa0 <BR>\\r<BR>\\r</P>\\r<P>Designs and develops high quality, scalable and robust solutions using Java, Spring, Hibernate, JSPs, XML and/or SQL as well as other internal tools.\xa0 Works with senior Java developers, leads, web designers, project managers or database developers, to deliver a rich experience for users through a commissioning and deployable metadata system.</P>'

# %% [markdown]
# ### Load Indeed dataset

# %%
i_jobs = pd.read_csv('../offline-datasets/Indeed-jobs/data+science+consultantLondon_IndeedJobs.csv')

# %%
# Drop 1st column
i_jobs.drop('Unnamed: 0', axis=1, inplace=True)

# %%
i_jobs.head()
# Out:
#   Location                        Company  \
# 0   London       Mango Business Solutions
# 1   London  Cambridge Healthcare Research
# 2   London            managementsolutions
# 3   London             GreySpark Partners
# 4   London                        Celonis
#
#                                            Job Title  \
# 0                                    Data Consultant
# 1                               Associate Consultant
# 2                     DATA SCIENCE CONSULTANT LONDON
# 3     Data Science Consultant, Data Analyst (London)
# 4  Intern/Working Student Data Science / Business...
#
#                                      Job Description                 Salary
# 0  A data consultant experienced in working in a ...  No salary information
# 1  Where appropriate manages external contractors...  No salary information
# 2  You will be working in key projects for leadin...  No salary information
# 3  Understanding of data best practices and basic...  No salary information
# ...

# %%
i_jobs.describe()
# Out:
#        Location    Company             Job Title  \
# count        79         79                    79
# unique        1         51                    60
# top      London  Capgemini  Associate Consultant
# freq         79          8                     3
#
#                                           Job Description  \
# count                                                  79
# unique                                                 60
# top     You will creatively apply data science approac...
# freq                                                    3
#
#                        Salary
# count                      79
# unique                      1
# top     No salary information
# freq                       79

# %%
#i_jobs['Company'].value_counts()

# %% [markdown]
# ### Import Spacy Library

# %%
# Perform standard imports
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
# Import the displaCy library
from spacy import displacy

# %%
k_jobs['Job Description'][6]
# Out:
# '<P><STRONG>As a member of the Web and Portal Development Team of the BHS Information Services Department in Louisville, KY the Java Developer- Intermediate designs, develops, and implements web-based Java applications to support business requirements.</STRONG>\xa0 Follows approved life cycle methodologies, creates design solutions and performs program coding and testing.\xa0 Resolves technical issues through debugging, research, and investigation.\xa0 Relies on extensive experience and judgment to plan and accomplish software development goals and user-required deliverables.\xa0 <BR>\\r<BR>\\r</P>\\r<P>Designs and develops high quality, scalable and robust solutions using Java, Spring, Hibernate, JSPs, XML and/or SQL as well as other internal tools.\xa0 Works with senior Java developers, leads, web designers, project managers or database developers, to deliver a rich experience for users through a commissioning and deployable metadata system.</P>'

# %%
jd_0 = nlp(k_jobs['Job Description'][0])

# %%
jd_15 = nlp(k_jobs['Job Description'][15])

# %%
print(jd_0.text)
# Out:
# This Administrative Assistant position is responsible for performing a variety of clerical and administrative support functions in the areas of communications, data entry and retrieval, typing, filing, copying, and coordination of related administrative activities. \r\n\r\nJOB REQUIREMENTS:\r\nAttention to detail\r\nAbility to work in a fast paced environment\r\nInvoicing\r\nProficient in Word, Excel and Outlook\r\nOther Administrative responsibilities as needed.\r\n\r\nQUALIFICATIONS:\r\nHigh School Diploma\r\nAdministrative Assistant Experience\r\n1-2 Years work experience\r\nWorking knowledge of all basic office machines (fax, copier, 10key, etc.)\r\nStrong verbal and written communication skills\r\nStrong work ethic.

# %%
print(jd_15)
# Out:
# Management Executives of a growing healthcare management firm are seeking a top-notch Executive Assistant with some experience in accounting as well.  The right person for this position will be expected to perform clerical support work for the executives, including standard duties such as managing phone, mail and email correspondence, filing and other day-to-day responsibilities.  In addition this person will be expected to keep up-to-date financial records and provide cash management for both personal and business related activities of the Executives.  This position can be at times demanding and challenging, requiring the right candidate to be efficient with multi-tasking as well as organized.  There will likely be much interaction with co-workers and with customers/acquaintences which will require a mastery of inter-personal skills and an understanding of the various personal and business interests of the Executives.  Although the hours for this position are generally regular busin
# ...

# %%
jd_15.ents[0].text
# Out:
# 'Management Executives'

# %%
spacy.explain(jd_15.ents[0].label_)
# Out:
# 'Companies, agencies, institutions, etc.'

# %%
jd_15.ents[0].label_
# Out:
# 'ORG'

# %%
sf.show_entities(jd_0)
# Out:
# Word - GPE - Countries, cities, states
# Excel - PRODUCT - Objects, vehicles, foods, etc. (not services)
# School Diploma\r\nAdministrative Assistant Experience\r\n1-2 Years - ORG - Companies, agencies, institutions, etc.
# 10key - DATE - Absolute or relative dates or periods

# %%
i_jobs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79 entries, 0 to 78
# Data columns (total 5 columns):
# Location           79 non-null object
# Company            79 non-null object
# Job Title          79 non-null object
# Job Description    79 non-null object
# Salary             79 non-null object
# dtypes: object(5)
# memory usage: 3.2+ KB

# %% [markdown]
# ### Transforming Job Descriptions to NLP docs using Spacy

# %% [markdown]
# #### Indeed Job Descriptions

# %%
i_jobs.isnull().sum()
# Out:
# Location           0
# Company            0
# Job Title          0
# Job Description    0
# Salary             0
# dtype: int64

# %%
nlp_jd = []
for jd in i_jobs['Job Description']:
    nlp_jd.append(nlp(jd))

# %%
sf.show_entities(nlp_jd[5])
# Out:
#  - GPE - Countries, cities, states
# Physics - ORG - Companies, agencies, institutions, etc.
#
#  - GPE - Countries, cities, states
# Problem - NORP - Nationalities or religious or political groups
# daily - DATE - Absolute or relative dates or periods

# %%
#i_jobs['NLP Job Description'] = pd.DataFrame(nlp_jd)

# %%
len(nlp_jd)
# Out:
# 79

# %%
for i in nlp_jd:
    sf.show_entities(i)
    print('\n\n')
# Out:
#  - GPE - Countries, cities, states
#
#
#
#
#  - GPE - Countries, cities, states
#
#
#
# Discovery - PRODUCT - Objects, vehicles, foods, etc. (not services)
# Simulation - WORK_OF_ART - Titles of books, songs, etc.
#
#
#
#
#  - GPE - Countries, cities, states
# GreySpark - GPE - Countries, cities, states
# Data Practice - ORG - Companies, agencies, institutions, etc.
#
#
#
# Business Intelligence - ORG - Companies, agencies, institutions, etc.
#
#  - GPE - Countries, cities, states
#
#
#
#
#  - GPE - Countries, cities, states
# Physics - ORG - Companies, agencies, institutions, etc.
#
#  - GPE - Countries, cities, states
# Problem - NORP - Nationalities or religious or political groups
# daily - DATE - Absolute or relative dates or periods
#
#
#
# Business Intelligence - ORG - Companies, agencies, institutions, etc.
#
#  - GPE - Countries, cities, states
#
#
#
# Capgemini Invent - ORG - Companies, agencies, institutions, etc.
#
#
#
# No named entities found.
#
#
#
# ...

# %% [markdown]
# #### Kaggle Job Descriptions

# %%
k_jobs.isnull().sum()
# Out:
# Location           0
# Company            0
# Job Title          0
# Job Description    0
# Salary             0
# E-mail             0
# dtype: int64

# %%
len(k_jobs['Job Description'][:1000])
# Out:
# 1000

# %%
nlp_jd_k = []
for jd in k_jobs['Job Description'][:100]:
    nlp_jd_k.append(nlp(jd))

# %%
for i in nlp_jd_k:
    sf.show_entities(i)
    print('\n\n')
# Out:
# Word - GPE - Countries, cities, states
# Excel - PRODUCT - Objects, vehicles, foods, etc. (not services)
# School Diploma\r\nAdministrative Assistant Experience\r\n1-2 Years - ORG - Companies, agencies, institutions, etc.
# 10key - DATE - Absolute or relative dates or periods
#
#
#
# the Board of Trustees - ORG - Companies, agencies, institutions, etc.
# 3+ years - DATE - Absolute or relative dates or periods
# Microsoft Word - PERSON - People, including fictional
# Excel - PRODUCT - Objects, vehicles, foods, etc. (not services)
# Power Point - PRODUCT - Objects, vehicles, foods, etc. (not services)
# QuickBooks - ORG - Companies, agencies, institutions, etc.
# Kenneth.harker@healthcentral.org EOE - PERSON - People, including fictional
# Source - Orlando Sentinel - PERSON - People, including fictional
#
#
#
# Handbag - PERSON - People, including fictional
# Inventory Depmts - PERSON - People, including fictional
# the Western Industry - ORG - Companies, agencies, institutions, etc.
# ...

# %%
for i in nlp_jd_k:
    for sent in i.sents:
        docx = nlp(sent.text)
        if docx.ents:
            displacy.render(docx, style='ent', jupyter=True)
#            doc, style='ent', options=options
        else:
            print(docx.text)
        print('\n')
    print('\n\n')
# Out:
# This Administrative Assistant position is responsible for performing a variety of clerical and administrative support functions in the areas of communications, data entry and retrieval, typing, filing, copying, and coordination of related administrative activities.
# <div class="entities" style="line-height: 2.5">\r\n\r\nJOB REQUIREMENTS:\r\nAttention to detail\r\nAbility to work in a fast paced environment\r\nInvoicing\r\nProficient in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Word
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# ...

# %% [markdown]
# ## Pre-processing

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %% [markdown]
# #### Use Count Vectorizer

# %%
cv = CountVectorizer(max_df=0.95, min_df=2, stop_words='english')

# %%
dtm = cv.fit_transform(k_jobs['Job Description'])

# %%
dtm_i = cv.fit_transform(i_jobs['Job Description'])

# %%
dtm
# Out:
# <72292x28293 sparse matrix of type '<class 'numpy.int64'>'
# 	with 8514975 stored elements in Compressed Sparse Row format>

# %%
dtm_i
# Out:
# <79x232 sparse matrix of type '<class 'numpy.int64'>'
# 	with 795 stored elements in Compressed Sparse Row format>

# %% [markdown]
# #### User Tf-IDF Vectorizer

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(max_df=0.95, min_df=2, stop_words='english')

# %%
dtm2 = vectorizer.fit_transform(k_jobs['Job Description'])

# %%
dtm2_i = vectorizer.fit_transform(i_jobs['Job Description'])

# %%
dtm2
# Out:
# <72292x28293 sparse matrix of type '<class 'numpy.float64'>'
# 	with 8514975 stored elements in Compressed Sparse Row format>

# %%
dtm2_i
# Out:
# <79x232 sparse matrix of type '<class 'numpy.float64'>'
# 	with 795 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ## LDA

# %%
from sklearn.decomposition import LatentDirichletAllocation

# %% [markdown]
# #### Kaggle Job Descriptions

# %%
LDA = LatentDirichletAllocation(n_components=7,random_state=42)

# %%
# This can take awhile, we're dealing with a large amount of documents!
LDA.fit(dtm)
# Out:
# LatentDirichletAllocation(n_components=7, random_state=42)

# %%
# Fit again using dtm2 (TfIdf)
LDA2 = LDA.fit(dtm2)

# %%
# Check features length
len(cv.get_feature_names())
# Out:
# 28293

# %%
# Check vectors length
len(vectorizer.get_feature_names())
# Out:
# 28293

# %%
import random

# %%
for i in range(10):
    random_word_id = random.randint(0,28293)
    print(cv.get_feature_names()[random_word_id])
# Out:
# tparticipates
# rfamily
# client
# ncreate
# smoother
# rmaintenance
# alvin
# mopping
# tm
# tawareness

# %% [markdown]
# #### Check number of components

# %%
len(LDA.components_)
# Out:
# 7

# %%
len(LDA2.components_)
# Out:
# 7

# %% [markdown]
# ### Top 10 words per topic

# %%
for index,topic in enumerate(LDA.components_):
    print(f'THE TOP 10 WORDS FOR TOPIC #{index}')
    print([cv.get_feature_names()[i] for i in topic.argsort()[-15:]])
    print('\n')
# Out:
# THE TOP 10 WORDS FOR TOPIC #0
# ['position', 'financial', 'accountant', 'style', 'ul', 'administrative', 'customer', 'experience', 'div', 'project', 'nbsp', 'strong', 'br', 'li', 'span']
#
#
# THE TOP 10 WORDS FOR TOPIC #1
# ['div', 'market', 'sales', 'industry', 'community', 'franchisees', 'seasonal', 'support', 'learn', 'ongoing', 'preparation', 'span', 'br', 'liberty', 'tax']
#
#
# THE TOP 10 WORDS FOR TOPIC #2
# ['card', 'tools', 'em', 'media', 'li', 'list', 'protected', 'payment', 'span', 'central', 'sales', 'snap', 'business', 'franchise', 'strong']
#
#
# THE TOP 10 WORDS FOR TOPIC #3
# ['business', 'work', 'tools', 'ul', 'need', 'career', 'equipment', 'usa', 'span', 'matco', 'sales', 'nbsp', 'strong', 'aflac', 'li']
#
#
# THE TOP 10 WORDS FOR TOPIC #4
# ['start', 'people', 'growing', 'strong', 'looking', 'income', 'nbsp', 'opportunities', 'summer', 'regular', 'vector', 'span', 'rsquo', 'time', 'li']
#
#
# THE TOP 10 WORDS FOR TOPIC #5
# ...

# %% [markdown]
# #### Indeed Job descritpions

# %%
LDA = LatentDirichletAllocation(n_components=7,random_state=42)

# %%
# This can take awhile, we're dealing with a large amount of documents!
LDA.fit(dtm_i)
# Out:
# LatentDirichletAllocation(n_components=7, random_state=42)

# %%
# Fit again using dtm2 (TfIdf)
LDA2 = LDA.fit(dtm2_i)

# %%
# Check features length
len(cv.get_feature_names())
# Out:
# 232

# %%
# Check vectors length
len(vectorizer.get_feature_names())
# Out:
# 232

# %%
import random

# %%
for i in range(10):
    random_word_id = random.randint(0,232)
    print(cv.get_feature_names()[random_word_id])
# Out:
# bi
# processes
# processing
# goal
# verisk
# delivering
# nasdaq
# using
# knowledge
# highly

# %% [markdown]
# #### Check number of components

# %%
len(LDA.components_)
# Out:
# 7

# %%
len(LDA2.components_)
# Out:
# 7

# %% [markdown]
# ### Top 10 words per topic

# %%
for index,topic in enumerate(LDA.components_):
    print(f'THE TOP 10 WORDS FOR TOPIC #{index}')
    print([cv.get_feature_names()[i] for i in topic.argsort()[-8:]])
    print('\n')
# Out:
# THE TOP 10 WORDS FOR TOPIC #0
# ['data', 'solutions', 'complex', 'clients', 'sources', 'experience', 'needed', 'shoulder']
#
#
# THE TOP 10 WORDS FOR TOPIC #1
# ['analytical', 'help', 'statistical', 'banking', 'international', 'data', 'projects', 'processes']
#
#
# THE TOP 10 WORDS FOR TOPIC #2
# ['knowledge', 'degree', 'practice', 'science', 'quality', 'ensure', 'information', 'data']
#
#
# THE TOP 10 WORDS FOR TOPIC #3
# ['delivery', 'information', 'systems', 'wide', 'solutions', 'computer', 'range', 'including']
#
#
# THE TOP 10 WORDS FOR TOPIC #4
# ['substantial', 'analytics', 'technical', 'science', 'know', 'data', 'teams', 'consultants']
#
#
# THE TOP 10 WORDS FOR TOPIC #5
# ['verisk', 'professional', 'nasdaq', 'provides', 'management', 'key', 'developments', 'data']
#
#
# THE TOP 10 WORDS FOR TOPIC #6
# ['analysis', 'discovery', 'science', 'experience', 'modelling', 'analytics', 'working', 'data']

# %%
# Author: Olivier Grisel <olivier.grisel@ensta.org>
#         Lars Buitinck
#         Chyi-Kwei Yau <chyikwei.yau@gmail.com>
# License: BSD 3 clause

from time import time

from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import NMF, LatentDirichletAllocation
#from sklearn.datasets import fetch_20newsgroups

n_samples = 2000
n_features = 100
n_components = 7
n_top_words = 20


def print_top_words(model, feature_names, n_top_words):
    for topic_idx, topic in enumerate(model.components_):
        message = "Topic #%d: " % topic_idx
        message += " ".join([feature_names[i]
                             for i in topic.argsort()[:-n_top_words - 1:-1]])
        print(message)
    print()

# %%
# Load the 20 newsgroups dataset and vectorize it. We use a few heuristics
# to filter out useless terms early on: the posts are stripped of headers,
# footers and quoted replies, and common English words, words occurring in
# only one document or in at least 95% of the documents are removed.

print("Loading dataset...")
t0 = time()
data, _ = fetch_20newsgroups(shuffle=True, random_state=1,
                             remove=('headers', 'footers', 'quotes'),
                             return_X_y=True)
data_samples = data[:n_samples]
print("done in %0.3fs." % (time() - t0))
# Out:
# Loading dataset...
# done in 1.129s.

# %% [markdown]
# ### Loading Kaggle Dataset

# %%
print("Loading dataset...")
t0 = time()
k_jobs_samples = k_jobs['Job Description'][:n_samples]
print("done in %0.3fs." % (time() - t0))
# Out:
# Loading dataset...
# done in 0.000s.

# %% [markdown]
# ### Loading Indeed Dataset

# %%
print("Loading dataset...")
t0 = time()
i_jobs_samples = i_jobs['Job Description'][:75]
print("done in %0.3fs." % (time() - t0))
# Out:
# Loading dataset...
# done in 0.000s.

# %% [markdown]
# ### NMF

# %% [markdown]
# #### TFIDF vectorizer

# %%
# Use tf-idf features for NMF.
print("Extracting tf-idf features for NMF...")
tfidf_vectorizer = TfidfVectorizer(max_df=0.95, min_df=2,
                                   max_features=n_features,
                                   stop_words='english')


t0 = time()

k_tfidf = tfidf_vectorizer.fit_transform(k_jobs_samples)
i_tfidf = tfidf_vectorizer.fit_transform(i_jobs_samples)
#tfidf = tfidf_vectorizer.fit_transform(data_samples)

print("done in %0.3fs." % (time() - t0))
# Out:
# Extracting tf-idf features for NMF...
# done in 0.330s.

# %% [markdown]
# ##### Fit NMF Model  - Frobenius norm

# %%
# Fit the NMF model
print("Fitting the NMF model (Frobenius norm) with tf-idf features, "
      "n_samples=%d and n_features=%d..."
      % (n_samples, n_features))
t0 = time()
k_nmf = NMF(n_components=n_components, random_state=1,
          alpha=.1, l1_ratio=.5).fit(k_tfidf)
print("done in %0.3fs." % (time() - t0))

print("\nTopics in NMF model (Frobenius norm):")
tfidf_feature_names = tfidf_vectorizer.get_feature_names()
print_top_words(k_nmf, tfidf_feature_names, n_top_words)
# Out:
# Fitting the NMF model (Frobenius norm) with tf-idf features, n_samples=2000 and n_features=100...
# done in 0.312s.
#
# Topics in NMF model (Frobenius norm):
# Topic #0: sources techniques areas focus including turn day customers results workshops change teams technical transformation models engineering driven insights analytic analytics
# Topic #1: team government areas manage operations systems financial services developments complex workshops equivalent transformation insight insights bi science develop developing statistical
# Topic #2: focus turn bi quality teams customers shoulder work science technical substantial expertise environment processes banking leading looking mathematics experience operations
# Topic #3: client modeling sources science focus solutions working key customers project leading areas insights bi skills shoulder quality substantial turn new
# ...

# %% [markdown]
# ##### Fit NMF Model  - Generalized Kullback-Leibler divergence

# %%
# Fit the NMF model
print("Fitting the NMF model (generalized Kullback-Leibler divergence) with "
      "tf-idf features, n_samples=%d and n_features=%d..."
      % (n_samples, n_features))
t0 = time()
k_nmf = NMF(n_components=n_components, random_state=1,
          beta_loss='kullback-leibler', solver='mu', max_iter=1000, alpha=.1,
          l1_ratio=.5).fit(k_tfidf)
print("done in %0.3fs." % (time() - t0))

print("\nTopics in NMF model (generalized Kullback-Leibler divergence):")
tfidf_feature_names = tfidf_vectorizer.get_feature_names()
print_top_words(k_nmf, tfidf_feature_names, n_top_words)
# Out:
# Fitting the NMF model (generalized Kullback-Leibler divergence) with tf-idf features, n_samples=2000 and n_features=100...
# done in 0.753s.
#
# Topics in NMF model (generalized Kullback-Leibler divergence):
# Topic #0: sources focus science substantial turn customers skills shoulder including systems areas software knowledge experience technology workshops transformation quantitative teams work
# Topic #1: team government areas manage operations systems financial developments services complex workshops equivalent transformation insight insights bi developing develop statistical environment
# Topic #2: focus turn science customers areas key shoulder project working quality information work leading expertise technology looking banking teams develop design
# Topic #3: client modeling science solutions working key project leading customers insights areas quality skills bi shoulder new know consultants degree analytical
# ...

# %% [markdown]
# ### LDA

# %% [markdown]
# ##### TF Vectorizer

# %%
# Use tf (raw term count) features for LDA.
print("Extracting tf features for LDA...")
tf_vectorizer = CountVectorizer(max_df=0.95, min_df=2,
                                max_features=n_features,
                                stop_words='english')
t0 = time()
tf = tf_vectorizer.fit_transform(data_samples)
print("done in %0.3fs." % (time() - t0))
print()

# %% [markdown]
# ##### Fit Model

# %%
print("Fitting LDA models with tf features, "
      "n_samples=%d and n_features=%d..."
      % (n_samples, n_features))
lda = LatentDirichletAllocation(n_components=n_components, max_iter=5,
                                learning_method='online',
                                learning_offset=50.,
                                random_state=0)
t0 = time()
lda.fit(tf)
print("done in %0.3fs." % (time() - t0))

print("\nTopics in LDA model:")
tf_feature_names = tf_vectorizer.get_feature_names()
print_top_words(lda, tf_feature_names, n_top_words)

# %%
# Fit the NMF model
print("Fitting the NMF model (Frobenius norm) with tf-idf features, "
      "n_samples=%d and n_features=%d..."
      % (n_samples, n_features))
t0 = time()
nmf = NMF(n_components=n_components, random_state=1,
          alpha=.1, l1_ratio=.5).fit(tfidf)
print("done in %0.3fs." % (time() - t0))

print("\nTopics in NMF model (Frobenius norm):")
tfidf_feature_names = tfidf_vectorizer.get_feature_names()
print_top_words(nmf, tfidf_feature_names, n_top_words)

# Fit the NMF model
print("Fitting the NMF model (generalized Kullback-Leibler divergence) with "
      "tf-idf features, n_samples=%d and n_features=%d..."
      % (n_samples, n_features))
t0 = time()
nmf = NMF(n_components=n_components, random_state=1,
          beta_loss='kullback-leibler', solver='mu', max_iter=1000, alpha=.1,
          l1_ratio=.5).fit(tfidf)
print("done in %0.3fs." % (time() - t0))

print("\nTopics in NMF model (generalized Kullback-Leibler divergence):")
tfidf_feature_names = tfidf_vectorizer.get_feature_names()
print_top_words(nmf, tfidf_feature_names, n_top_words)

print("Fitting LDA models with tf features, "
      "n_samples=%d and n_features=%d..."
      % (n_samples, n_features))
lda = LatentDirichletAllocation(n_components=n_components, max_iter=5,
                                learning_method='online',
                                learning_offset=50.,
                                random_state=0)
t0 = time()
lda.fit(tf)
print("done in %0.3fs." % (time() - t0))

print("\nTopics in LDA model:")
tf_feature_names = tf_vectorizer.get_feature_names()
print_top_words(lda, tf_feature_names, n_top_words)
